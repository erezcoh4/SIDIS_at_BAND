# %% [markdown]
# # Unagged cross-section ratio of $(e,e'\pi^+)/(e,e'\pi^+)$
#
# $$\left(\frac{\sigma(e,e'\pi^+)}{\sigma(e,e'\pi^+)}\right)$$
#
# last edit July-14, 2022

# %% [markdown]
# ## Imports and definitions

# %%
import sys; 
software_path = '/Users/erezcohen/Desktop/Software/'
sys.path.insert(0, software_path + '/mySoftware/Python/');
sys.path.insert(0, software_path + '/CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/AcceptanceCorrections/');
sys.path.insert(0, software_path + '/CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/');
from my_tools                     import *; 
from plot_tools                   import *;
from my_data_analysis_tools       import *;
from acceptance_correction_tools  import *;
from sidis_analysis_tools         import *;
from event_selection_tools        import *;
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/42/n5_htl9n34j9wpgd5rqsnmv40000gn/T/ipykernel_5240/3765919510.py in <module>
#       8 from my_data_analysis_tools       import *;
#       9 from acceptance_correction_tools  import *;
# ---> 10 from sidis_analysis_tools         import *;
#      11 from event_selection_tools        import *;
#
# ~/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py in <module>
#       1 import numpy as np, pandas as pd, matplotlib.pyplot as plt, matplotlib as mpl
#       2 sidis_path = '/Users/erezcohen/Desktop/Software/'
# ----> 3 import sys; sys.path.insert(0, software_path + '/mySoftware/Python/');
#       4 import sys; sys.path.insert(0, software_path + '/CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/');
#       5 from my_tools               import *;
#
# NameError: name 'software_path' is not defined

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, matplotlib as mpl
sidis_path = '/Users/erezcohen/Desktop/Software/'
import sys; sys.path.insert(0, software_path + '/mySoftware/Python/');
import sys; sys.path.insert(0, software_path + '/CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/');
from my_tools               import *;
from plot_tools             import *;
from my_data_analysis_tools import *;
from event_selection_tools  import *;

# %% [markdown]
# ## (1) Load data

# %%
load_SIDIS_data( Nruns = -1, do_e_e_pi_n=False , fdebug=0)
# Out:
# Run number  6421 (1/86 runs)
# Loaded 632087  (e,e'π+) events
# Loaded 272140  (e,e'π-) events
# Run number  6422 (2/86 runs)
# Loaded 601973  (e,e'π+) events
# Loaded 257778  (e,e'π-) events
# Run number  6426 (3/86 runs)
# Loaded 534955  (e,e'π+) events
# Loaded 229279  (e,e'π-) events
# Run number  6429 (4/86 runs)
# Loaded 675433  (e,e'π+) events
# Loaded 289018  (e,e'π-) events
# Run number  6430 (5/86 runs)
# Loaded 129435  (e,e'π+) events
# Loaded 55524  (e,e'π-) events
# Run number  6431 (6/86 runs)
# Loaded 527395  (e,e'π+) events
# Loaded 226502  (e,e'π-) events
# Run number  6432 (7/86 runs)
# Loaded 658456  (e,e'π+) events
# Loaded 282291  (e,e'π-) events
# Run number  6433 (8/86 runs)
# Loaded 740198  (e,e'π+) events
# Loaded 313208  (e,e'π-) events
# Run number  6437 (9/86 runs)
# Loaded 258946  (e,e'π+) events
# Loaded 109952  (e,e'π-) events
# Run number  6442 (10/86 runs)
# Loaded 702201  (e,e'π+) events
# Loaded 298126  (e,e'π-) events
# Run number  6444 (11/86 runs)
# Loaded 125666  (e,e'π+) events
# Loaded 53726  (e,e'π-) events
# Run number  6445 (12/86 runs)
# Loaded 644767  (e,e'π+) events
# Loaded 272760  (e,e'π-) events
# Run number  6449 (13/86 runs)
# Loaded 632979  (e,e'π+) events
# Loaded 268751  (e,e'π-) events
# Run number  6450 (14/86 runs)
# Loaded 653454  (e,e'π+) events
# Loaded 277404  (e,e'π-) events
# Run number  6451 (15/86 runs)
# Loaded 649401  (e,e'π+) events
# Loaded 276214  (e,e'π-) events
# Run number  6452 (16/86 runs)
# Loaded 696718  (e,e'π+) events
# Loaded 297799  (e,e'π-) events
# Run number  6453 (17/86 runs)
# Loaded 649620  (e,e'π+) events
# Loaded 275416  (e,e'π-) events
# Run number  6454 (18/86 runs)
# Loaded 221761  (e,e'π+) events
# Loaded 94459  (e,e'π-) events
# Run number  6455 (19/86 runs)
# Loaded 659670  (e,e'π+) events
# Loaded 280151  (e,e'π-) events
# Run number  6456 (20/86 runs)
# Loaded 649547  (e,e'π+) events
# Loaded 275220  (e,e'π-) events
# Run number  6457 (21/86 runs)
# Loaded 260083  (e,e'π+) events
# Loaded 110059  (e,e'π-) events
# Run number  6461 (22/86 runs)
# Loaded 610052  (e,e'π+) events
# Loaded 259841  (e,e'π-) events
# Run number  6462 (23/86 runs)
# Loaded 678921  (e,e'π+) events
# Loaded 289232  (e,e'π-) events
# Run number  6463 (24/86 runs)
# Loaded 588960  (e,e'π+) events
# Loaded 250411  (e,e'π-) events
# Run number  6464 (25/86 runs)
# Loaded 302800  (e,e'π+) events
# Loaded 128650  (e,e'π-) events
# Run number  6465 (26/86 runs)
# Loaded 710176  (e,e'π+) events
# Loaded 300894  (e,e'π-) events
# Run number  6466 (27/86 runs)
# Loaded 654264  (e,e'π+) events
# Loaded 278819  (e,e'π-) events
# Run number  6467 (28/86 runs)
# Loaded 655477  (e,e'π+) events
# Loaded 278092  (e,e'π-) events
# Run number  6468 (29/86 runs)
# Loaded 189533  (e,e'π+) events
# Loaded 80797  (e,e'π-) events
# Run number  6470 (30/86 runs)
# Loaded 342333  (e,e'π+) events
# Loaded 145720  (e,e'π-) events
# Run number  6472 (31/86 runs)
# Loaded 707159  (e,e'π+) events
# Loaded 299968  (e,e'π-) events
# Run number  6473 (32/86 runs)
# Loaded 183160  (e,e'π+) events
# Loaded 77958  (e,e'π-) events
# Run number  6474 (33/86 runs)
# Loaded 707944  (e,e'π+) events
# Loaded 300175  (e,e'π-) events
# Run number  6475 (34/86 runs)
# Loaded 712816  (e,e'π+) events
# Loaded 302537  (e,e'π-) events
# Run number  6476 (35/86 runs)
# Loaded 467874  (e,e'π+) events
# Loaded 198226  (e,e'π-) events
# Run number  6479 (36/86 runs)
# Loaded 740166  (e,e'π+) events
# Loaded 314933  (e,e'π-) events
# Run number  6481 (37/86 runs)
# Loaded 690718  (e,e'π+) events
# Loaded 292486  (e,e'π-) events
# Run number  6482 (38/86 runs)
# Loaded 690576  (e,e'π+) events
# Loaded 292675  (e,e'π-) events
# Run number  6483 (39/86 runs)
# Loaded 509951  (e,e'π+) events
# Loaded 217560  (e,e'π-) events
# Run number  6484 (40/86 runs)
# Loaded 701274  (e,e'π+) events
# Loaded 296346  (e,e'π-) events
# Run number  6485 (41/86 runs)
# Loaded 338094  (e,e'π+) events
# Loaded 142894  (e,e'π-) events
# Run number  6486 (42/86 runs)
# Loaded 758033  (e,e'π+) events
# Loaded 321794  (e,e'π-) events
# Run number  6488 (43/86 runs)
# Loaded 752772  (e,e'π+) events
# Loaded 320163  (e,e'π-) events
# Run number  6489 (44/86 runs)
# Loaded 672750  (e,e'π+) events
# Loaded 285248  (e,e'π-) events
# Run number  6491 (45/86 runs)
# Loaded 693333  (e,e'π+) events
# Loaded 295484  (e,e'π-) events
# Run number  6498 (46/86 runs)
# Loaded 628367  (e,e'π+) events
# Loaded 266711  (e,e'π-) events
# Run number  6499 (47/86 runs)
# Loaded 615755  (e,e'π+) events
# Loaded 262541  (e,e'π-) events
# Run number  6502 (48/86 runs)
# Loaded 741804  (e,e'π+) events
# Loaded 314403  (e,e'π-) events
# Run number  6510 (49/86 runs)
# Loaded 252897  (e,e'π+) events
# Loaded 108233  (e,e'π-) events
# Run number  6511 (50/86 runs)
# Loaded 493267  (e,e'π+) events
# Loaded 209801  (e,e'π-) events
# Run number  6512 (51/86 runs)
# Loaded 605100  (e,e'π+) events
# Loaded 256916  (e,e'π-) events
# Run number  6513 (52/86 runs)
# Loaded 737728  (e,e'π+) events
# Loaded 314449  (e,e'π-) events
# Run number  6514 (53/86 runs)
# Loaded 693528  (e,e'π+) events
# Loaded 294536  (e,e'π-) events
# Run number  6522 (54/86 runs)
# Loaded 645069  (e,e'π+) events
# Loaded 274196  (e,e'π-) events
# Run number  6523 (55/86 runs)
# Loaded 665783  (e,e'π+) events
# Loaded 283422  (e,e'π-) events
# Run number  6524 (56/86 runs)
# Loaded 704607  (e,e'π+) events
# Loaded 297667  (e,e'π-) events
# Run number  6525 (57/86 runs)
# Loaded 570398  (e,e'π+) events
# Loaded 235971  (e,e'π-) events
# Run number  6546 (58/86 runs)
# Loaded 400739  (e,e'π+) events
# Loaded 172111  (e,e'π-) events
# Run number  6547 (59/86 runs)
# Loaded 430868  (e,e'π+) events
# Loaded 183692  (e,e'π-) events
# Run number  6548 (60/86 runs)
# Loaded 408641  (e,e'π+) events
# Loaded 173138  (e,e'π-) events
# Run number  6549 (61/86 runs)
# Loaded 399292  (e,e'π+) events
# Loaded 168978  (e,e'π-) events
# Run number  6550 (62/86 runs)
# Loaded 403603  (e,e'π+) events
# Loaded 171657  (e,e'π-) events
# Run number  6557 (63/86 runs)
# Loaded 389866  (e,e'π+) events
# Loaded 166003  (e,e'π-) events
# Run number  6559 (64/86 runs)
# Loaded 406658  (e,e'π+) events
# Loaded 172676  (e,e'π-) events
# Run number  6560 (65/86 runs)
# Loaded 271321  (e,e'π+) events
# Loaded 114662  (e,e'π-) events
# Run number  6563 (66/86 runs)
# Loaded 164015  (e,e'π+) events
# Loaded 69535  (e,e'π-) events
# Run number  6565 (67/86 runs)
# Loaded 401661  (e,e'π+) events
# Loaded 169718  (e,e'π-) events
# Run number  6566 (68/86 runs)
# Loaded 406074  (e,e'π+) events
# Loaded 171995  (e,e'π-) events
# Run number  6567 (69/86 runs)
# Loaded 399814  (e,e'π+) events
# Loaded 169891  (e,e'π-) events
# Run number  6569 (70/86 runs)
# Loaded 404018  (e,e'π+) events
# Loaded 172970  (e,e'π-) events
# Run number  6570 (71/86 runs)
# Loaded 409533  (e,e'π+) events
# Loaded 173381  (e,e'π-) events
# Run number  6571 (72/86 runs)
# Loaded 418170  (e,e'π+) events
# Loaded 177077  (e,e'π-) events
# Run number  6572 (73/86 runs)
# Loaded 406291  (e,e'π+) events
# Loaded 172966  (e,e'π-) events
# Run number  6576 (74/86 runs)
# Loaded 389669  (e,e'π+) events
# Loaded 165431  (e,e'π-) events
# Run number  6577 (75/86 runs)
# Loaded 406250  (e,e'π+) events
# Loaded 172456  (e,e'π-) events
# Run number  6578 (76/86 runs)
# Loaded 269364  (e,e'π+) events
# Loaded 114424  (e,e'π-) events
# Run number  6582 (77/86 runs)
# Loaded 162581  (e,e'π+) events
# Loaded 68877  (e,e'π-) events
# Run number  6585 (78/86 runs)
# Loaded 404904  (e,e'π+) events
# Loaded 171990  (e,e'π-) events
# Run number  6586 (79/86 runs)
# Loaded 397163  (e,e'π+) events
# Loaded 168338  (e,e'π-) events
# Run number  6587 (80/86 runs)
# Loaded 271537  (e,e'π+) events
# Loaded 114977  (e,e'π-) events
# Run number  6589 (81/86 runs)
# Loaded 67432  (e,e'π+) events
# Loaded 28719  (e,e'π-) events
# Run number  6590 (82/86 runs)
# Loaded 417538  (e,e'π+) events
# Loaded 177359  (e,e'π-) events
# Run number  6591 (83/86 runs)
# Loaded 411852  (e,e'π+) events
# Loaded 174028  (e,e'π-) events
# Run number  6593 (84/86 runs)
# Loaded 399292  (e,e'π+) events
# Loaded 169156  (e,e'π-) events
# Run number  6595 (85/86 runs)
# Loaded 425371  (e,e'π+) events
# Loaded 180079  (e,e'π-) events
# Run number  6597 (86/86 runs)
# Loaded 123586  (e,e'π+) events
# Loaded 52175  (e,e'π-) events
# Done loading files.
#
# Total statistics:
# 42985287  (e,e'π+) events
# 18263985  (e,e'π-) events

# %% [markdown]
# ## (2) Apply selection cuts not previously imposed

# %%
import time

# %%
print('number of pi+ events: %.1f'%(len(e_e_pi['piplus'])/1e6),'M')
# Out:
# number of pi+ events: 43.0 M

# %%
Nevents = -1
t0= time.time()
e_e_pi_pass_cuts,_,_ = apply_further_selection_cuts_to_data(fdebug=1, 
                                                            NeventsMax=Nevents,
                                                            NMaxPerSubset=500000);
t1 = time.time() 
print("Time elapsed: %.2f"%(t1 - t0), 'sec (%g us/event)'%((t1 - t0)/Nevents*1.e6)) # CPU seconds elapsed (floating point)
# Out:
# Applying selection cuts not previously imposed
# (1) DATA
# (e,e'π)
# Apply a π+/π- acceptance matching cut on the in p-theta plane
# Applying p-theta on cut for piplus on 42985287 events
# Subdividing into 85 subsets up to 500000 events
# Applying p-theta on cut for piminus on 18263985 events
# Subdividing into 36 subsets up to 500000 events
# Apply a cut on the missing mass of a (e,e'π) reaction: 2.5<Mx<5.0 GeV/c2
# (e,e π+ )
# 42985287 events before cut
# 30700941 events after p-theta cut (71.4 %)
# 27820443 events after M_X cut (64.7 %)
# (e,e π- )
# 18263985 events before cut
# 17902692 events after p-theta cut (98.0 %)
# 16563892 events after M_X cut (90.7 %)
#
# Done applying selection cuts not previously imposed
# Time elapsed: 442.07 sec (-4.42066e+08 us/event)

# %% [markdown]
# ## (3) Extract cross-section ratio as a function of Bjorken $x$
# For a standing proton use $x_B$, defined as
# $ x_B = Q^2/2m_p\omega$

# %%
z_bins   = np.arange(0.3,0.8,0.1)
z_widths = 0.01*np.ones(len(z_bins))
x_bins   = np.linspace(0.2,0.6,11)
x        = (x_bins[1:] + x_bins[:-1])/2
x_err    = (x_bins[1:] - x_bins[:-1])/2
x_bins
# Out:
# array([0.2 , 0.24, 0.28, 0.32, 0.36, 0.4 , 0.44, 0.48, 0.52, 0.56, 0.6 ])

# %%
var_label = "standing proton x"
# var_label = "moving proton x"

if   var_label == "standing proton x":
    var    = 'xB'
    xlabel = "Bjorken $x$"
    
elif var_label == "moving proton x":
    var    = 'xPrime2'
    xlabel = "$x' = Q^2/(W'^2 - m_N^2 + Q^2)$"

# %%
Rpips2pims, Rpips2pims_errup, Rpips2pims_errdw = dict(), dict(), dict()
Y, dY = dict(),dict()
for z_bin,z_width in zip(z_bins,z_widths):
    z_min,z_max = z_bin-z_width,z_bin+z_width
    (Rpips2pims[z_bin],
     Rpips2pims_errup[z_bin], 
     Rpips2pims_errdw[z_bin],_,_) = compute_ratio_pips_to_pims(df_dict=e_e_pi_pass_cuts  , 
                                                             var=var, 
                                                             bins=x_bins, 
                                                             z_min=z_min,z_max=z_max)

    # fit to a constant 
    y    = Rpips2pims[z_bin]
    y_err= (Rpips2pims_errup[z_bin],Rpips2pims_errdw[z_bin])
    p,cov = np.polyfit(x,y,deg=0,cov=True)
    Y[z_bin],dY[z_bin] = p[0],cov[0,0]

    # print(z_bin,Rpips2pims_n[z_bin],Rpips2pims_n_errup[z_bin],Rpips2pims_n_errdw[z_bin])
print('done')
# Out:
# done

# %%
fig = plt.figure(figsize=(9,6))
ax  = fig.add_subplot(1,1,1)
for z_bin,z_width in zip(z_bins,z_widths):
    y    = Rpips2pims[z_bin]
    y_err= (Rpips2pims_errup[z_bin],Rpips2pims_errdw[z_bin])
    x_fit = np.linspace(np.min(x),np.max(x),100)
    y_dw = (Y[z_bin]-dY[z_bin])*np.ones(len(x_fit))
    y_up = (Y[z_bin]+dY[z_bin])*np.ones(len(x_fit))

    # plot
    l=ax.errorbar(x=x, xerr=x_err,  y=y, yerr=y_err,
                marker='o',markeredgecolor='k',
                label='$z=%.2f\pm%.2f, (\pi^+/\pi^-)=%.2f\pm%.2f$'%(z_bin,z_width,Y[z_bin],dY[z_bin]))
    
    ax.fill_between( x_fit, y_dw, y_up, color=l[0].get_color(), alpha=0.1)
set_axes(ax,xlabel,"$N(e,e'\pi^+)/N(e,e'\pi^-)$",
         title="$\pi^+/\pi^-$ ratio as a function of $x_B$ without a tagged neutron",
         do_add_grid=True, do_add_legend=True, fontsize=18,
        );
plt.legend(bbox_to_anchor=(1,1.05),loc='best',fontsize=18)

# %% [markdown]
# # (4) Save results to file

# %%
save_SIDIS_ratio_DataFrame(df_dict  = e_e_pi_pass_cuts,                                
                           x_var    = var ,                           
                           x_bins   = x_bins,                           
                           z_bins   = z_bins,                           
                           z_widths = z_widths,                           
                           fdebug   = 0,
                           prefix   = 'Untagged_SIDIS_ratio_',                           
                           suffix   = '')
# Out:
# saved /Users/erezcohen/Desktop/data/BAND/Results/Untagged_SIDIS_ratio_z_0.29-0.31.csv
# saved /Users/erezcohen/Desktop/data/BAND/Results/Untagged_SIDIS_ratio_z_0.39-0.41.csv
# saved /Users/erezcohen/Desktop/data/BAND/Results/Untagged_SIDIS_ratio_z_0.49-0.51.csv
# saved /Users/erezcohen/Desktop/data/BAND/Results/Untagged_SIDIS_ratio_z_0.59-0.61.csv
# saved /Users/erezcohen/Desktop/data/BAND/Results/Untagged_SIDIS_ratio_z_0.69-0.71.csv

# %% [markdown]
# ## load results and plot them

# %%
prefix = 'Untagged_SIDIS_ratio_'
suffix = ''
SIDIS_results = load_SIDIS_ratio_DataFrame(z_bins=z_bins,z_widths=z_widths,
                                           prefix = prefix, suffix = suffix, doPlotResults=True)

# %% [markdown]
# # (5) Extract modified results
# With no acceptance matching cut in $p-\theta$ plane

# %%
Nevents = -1
t0= time.time()
e_e_pi_pass_cuts_no_p_theta_cut,_,_ = apply_further_selection_cuts_to_data(fdebug=2,
                                                                           NeventsMax=Nevents, 
                                                                           doAcceptanceMatchingCut=False);
t1 = time.time() 
print("Time elapsed: %.2f"%(t1 - t0), 'sec (%g us/event)'%((t1 - t0)/Nevents*1.e6)) # CPU seconds elapsed (floating point)
# Out:
# Applying selection cuts not previously imposed
# (1) DATA
# (e,e'π)
# Apply a cut on the missing mass of a (e,e'π) reaction: 2.5<Mx<5.0 GeV/c2
# (e,e π+ )
# 42985287 events before cut
# 42985286 events after p-theta cut (100.0 %)
# 39809815 events after M_X cut (92.6 %)
# 29473349 events after further Kinematical cut (68.6 %)
# (e,e π- )
# 18263985 events before cut
# 18263984 events after p-theta cut (100.0 %)
# 16901516 events after M_X cut (92.5 %)
# 12979545 events after further Kinematical cut (71.1 %)
#
# Done applying selection cuts not previously imposed
# Time elapsed: 29.38 sec (-2.93803e+07 us/event)

# %%
save_SIDIS_ratio_DataFrame(df_dict  = e_e_pi_pass_cuts_no_p_theta_cut,                                
                           x_var    = var ,                           
                           x_bins   = x_bins,                           
                           z_bins   = z_bins,                           
                           z_widths = z_widths,                           
                           fdebug   = 0,
                           prefix   = 'Untagged_SIDIS_ratio_',                           
                           suffix   = '_No_AcceptanceMatchingCut')
# Out:
# saved /Users/erezcohen/Desktop/data/BAND/Results/Untagged_SIDIS_ratio_z_0.29-0.31_No_AcceptanceMatchingCut.csv
# saved /Users/erezcohen/Desktop/data/BAND/Results/Untagged_SIDIS_ratio_z_0.39-0.41_No_AcceptanceMatchingCut.csv
# saved /Users/erezcohen/Desktop/data/BAND/Results/Untagged_SIDIS_ratio_z_0.49-0.51_No_AcceptanceMatchingCut.csv
# saved /Users/erezcohen/Desktop/data/BAND/Results/Untagged_SIDIS_ratio_z_0.59-0.61_No_AcceptanceMatchingCut.csv
# saved /Users/erezcohen/Desktop/data/BAND/Results/Untagged_SIDIS_ratio_z_0.69-0.71_No_AcceptanceMatchingCut.csv

# %%
prefix = 'Untagged_SIDIS_ratio_'
suffix = '_No_AcceptanceMatchingCut'
SIDIS_results = load_SIDIS_ratio_DataFrame(prefix = prefix, suffix = suffix, doPlotResults=True)

# %% [markdown]
# # arxiv

# %% [markdown]
# ### Improve analysis timing with a focus on apply_further_selection_cuts_to_data()
# Check timing of the function and improve it, as well as memory usage

# %%
import timeit
timeit.timeit("apply_further_selection_cuts_to_data(fdebug=2, NeventsMax=-1)", 
              setup="from __main__ import apply_further_selection_cuts_to_data",number=1)
# Out:
# Applying selection cuts not previously imposed
# (1) DATA
# (e,e'π)
# Apply a π+/π- acceptance matching cut on the in p-theta plane
# 849943
# 564052
# applying p-theta cut only to 1234060 events
# 513369
# 271407
# Apply a cut on the missing mass of a (e,e'π) reaction: 2.5<Mx<5.0 GeV/c2
# (e,e π+ )
# 1234060 events before cut
# 1679299 events after p-theta cut (136.1 %)
# 1536045 events after M_X cut (124.5 %)
# (e,e π- )
# 529918 events before cut
# 1012857 events after p-theta cut (191.1 %)
# 937092 events after M_X cut (176.8 %)
#
# Done applying selection cuts not previously imposed
# 13.38524674799919

# %%
e_e_pi[pi_ch].keys()
# retain only the most important features to reduce memory usage by a large pandas DataFrame
reduced_e_e_pi = dict()
for pi_ch in pi_charge_names:
    reduced_e_e_pi[pi_ch] = e_e_pi[pi_ch][['runnum','evnum',
                                           'e_P','e_Theta','e_Phi', 
                                           'pi_P', 'pi_Theta', 'pi_Phi', 
                                           'Q2', 'W', 'xB', 'Zpi',
                                           'M_X', 'e_DC_sector', 'pi_DC_sector']]
    reduced_e_e_pi[pi_ch] = reduced_e_e_pi[pi_ch].astype({"evnum": int,
                                                          "e_P":np.half,"e_Theta":np.half,"e_Phi":np.half,
                                                          "pi_P":np.half,'pi_Theta':np.half, 'pi_Phi':np.half,
                                                          'Q2':np.half, 'W':np.half, 'xB':np.half, 'Zpi':np.half,
                                                          'M_X':np.half, })

reduced_e_e_pi[pi_ch][0:5]
# Out:
#    runnum  evnum       e_P   e_Theta     e_Phi      pi_P  pi_Theta    pi_Phi  \
# 0    6420    993  6.335938  0.175537  1.181641  1.421875  0.355469 -0.781250
# 1    6420   1655  4.992188  0.206055 -1.996094  2.199219  0.415039  1.062500
# 2    6420   2441  3.058594  0.283691  3.062500  4.175781  0.191284 -0.098450
# 3    6420   3793  3.445312  0.339600  2.103516  3.009766  0.212036  0.062195
# 4    6420   4165  4.324219  0.272461  0.204468  2.564453  0.572266 -2.738281
#
#          Q2         W        xB       Zpi       M_X  e_DC_sector  pi_DC_sector
# 0  1.985352  2.480469  0.273682  0.369629  3.259766            2             6
# 1  2.154297  2.916016  0.220337  0.423340  3.589844            5             2
# 2  2.492188  3.435547  0.185913  0.584961  3.662109            4             1
# 3  4.011719  3.089844  0.316406  0.446045  3.798828            3             1
# 4  3.255859  2.943359  0.295166  0.437012  3.421875            1             4

# %%
for pi_ch in pi_charge_names:
    print(pi_ch)
    print('before cuts')
    print(e_e_pi[pi_ch].info(memory_usage="deep",verbose=False))
    print(' ')    
    # print('reduced dataframe before cuts')
    # print(reduced_e_e_pi[pi_ch].info(memory_usage="deep",verbose=False))
    # print(' ')
    print('after cuts')
    print(e_e_pi_pass_cuts[pi_ch].info(memory_usage="deep",verbose=False))
    print(' ')
# Out:
# piplus
# before cuts
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1234060 entries, 0 to 601972
# Columns: 15 entries, runnum to pi_DC_sector
# dtypes: float16(11), int64(4)
# memory usage: 73.0 MB
# None
#
# after cuts
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1019530 entries, 0 to 632085
# Columns: 15 entries, runnum to pi_DC_sector
# dtypes: float16(11), int64(4)
# memory usage: 60.3 MB
# None
#
# piminus
# before cuts
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 529918 entries, 0 to 257777
# Columns: 15 entries, runnum to pi_DC_sector
# dtypes: float16(11), int64(4)
# memory usage: 31.3 MB
# None
#
# after cuts
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 489627 entries, 0 to 272139
# Columns: 15 entries, runnum to pi_DC_sector
# dtypes: float16(11), int64(4)
# memory usage: 29.0 MB
# None

# %%
e_e_pi_pass_cuts[pi_ch].index
# Out:
# Int64Index([    11,     11,     30,     30,     31,     31,     46,     46,
#                 55,     56,
#             ...
#             257738, 257742, 257742, 257745, 257748, 257748, 257771, 257771,
#             257772, 257772],
#            dtype='int64', length=937092)
