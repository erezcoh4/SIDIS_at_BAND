# %% [markdown]
# # Difference between untagged data in different versions of the code
# last edit Sep-14, 2022

# %% [markdown]
# ## Imports and definitions

# %%
import sys; 
software_path = '/Users/erezcohen/Desktop/Software/'
sys.path.insert(0, software_path + '/mySoftware/Python/');
sys.path.insert(0, software_path + '/CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/AcceptanceCorrections/');
sys.path.insert(0, software_path + '/CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/');
from my_tools                     import *; 
from plot_tools                   import *;
from my_data_analysis_tools       import *;
from acceptance_correction_tools  import *;
from sidis_analysis_tools         import *;
# from event_selection_tools        import *;

# %%
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['mathtext.fontset']    = 'stix'
plt.rcParams['font.family']         = 'STIXGeneral'

# %% [markdown]
# # (1) Load data:

# %%
main_data_path = '/Users/erezcohen/Desktop/data/BAND/'
subdirnames    = ["July_29_commit_338982b","Sep_14_Wcut0.5_commit_869e7a8","Sep_14_Wcut2.5_commit_741b80a"]
subdirlabels   = ["July-29,338982b","Sep-14, W>0.5, 869e7a8","Sep-14,W>2.5, 741b80a"]
subdircolors   = ['k','r','b']
 # "Aug_9_commit_2021402",

# %%
eepi,eepi_pass_cuts = dict(),dict()
for subdirname in subdirnames:
    print(subdirname)
    print('-------------')
    eepi[subdirname],_,_ = load_SIDIS_data( Nruns = 1,
                    main_data_path = main_data_path,
                    subdirname = "code_versions_July_Aug_2022/" + subdirname,
                    do_e_e_pi = True, do_e_e_pi_n = False, do_e_e_pi_FreeP=False, 
                    do_all_vars=True)
    eepi_pass_cuts[subdirname],_,_,_ = apply_further_selection_cuts_to_data(doApply_Mx_cut=False);
    print()
print('Done.')
# Out:
# July_29_commit_338982b
# -------------
# Run number  6421 (1/1 runs)
# Loaded 394332  d(e,e'π+) events
# Loaded 177122  d(e,e'π-) events
# Done loading files.
#
# Total statistics:
# 394332  d(e,e'π+)  events
# 177122  d(e,e'π-)  events
# Applying selection cuts not previously imposed
# (1) Applying cuts to d(e,e'π) data
# Apply a π+/π- acceptance matching cut on the in p-theta plane
# Applying p-theta on cut for piplus on 394332 events
# Subdividing into 1 subsets up to 500000 events
# subset 0 of index 0-394331
# Applying p-theta on cut for piminus on 177122 events
# Subdividing into 1 subsets up to 500000 events
# subset 0 of index 0-177121
# (e,e π+ )
# 394332 events after original cut (100.0 %)
# 286985 events after p-theta cut (72.8 %)
# 286985 events after Mx cut (72.8 %)
# 286985 events after Kinematical cut (72.8 %)
# (e,e π- )
# 177122 events after original cut (100.0 %)
# 172302 events after p-theta cut (97.3 %)
# 172302 events after Mx cut (97.3 %)
# ...

# %%
# eepi_pass_cuts[subdirname]

# %% [markdown]
# # (2) Monitoring plots

# %%
def plot_monitor_var(var,vlabel,bins,run=None,df_dict_arr=eepi):
    fig = plt.figure(figsize=(16,6), tight_layout=True)

    for pi_ch,pi_print,pi_label,pi_color,pi_idx in zip(pi_charge_names,pi_prints,pi_labels,pi_colors,[1,2]):
        ax = fig.add_subplot(1,2,pi_idx)
        title_str = "$(e,e'"+pi_print+")$"
        if run is not None:
            title_str = title_str + ", run %d"%run
            
        for subdirname,subdirlabel,subdircolor in zip(subdirnames,subdirlabels,subdircolors):
            df = df_dict_arr[subdirname][pi_ch]
            if run is not None:
                df = df[df.runnum==run]                
                # print(len(df),'events')
            plot_step_hist( df[var], bins=bins, density=False,
                           color=subdircolor, label=subdirlabel)
        set_axes(ax,vlabel,
                 'Frequency [a.u.]' , 
                 title=title_str,
                 do_add_grid=True, do_add_legend=True if pi_idx==2 else False);

# %%
# var,vlabel,bins = 'evnum',"evnum",np.linspace(0.622e8,0.623e8,100)# np.linspace(0,1.5e8,100)#np.linspace(0.622e8,0.623e8,100)# np.linspace(0,1.5e8,100)
# var,vlabel,bins = 'W',"$W$ [GeV/c$^2$]",np.linspace(2.3,5.5,100)
plot_monitor_var( 'W',"$W$ [GeV/c$^2$]",np.linspace(1.95,5.5,100) )

# %%
plot_monitor_var( 'evnum',"evnum",np.linspace(0,1.5e8,100), run=6421, df_dict_arr=eepi )
plot_monitor_var( 'evnum',"evnum",np.linspace(0,1.5e8,100), run=6422, df_dict_arr=eepi )
# plot_monitor_var( 'evnum',"evnum",np.linspace(0,1.5e8,100), run=6426, df_dict_arr=eepi )
# plot_monitor_var( 'evnum',"evnum",np.linspace(0,1.5e8,100), run=6429, df_dict_arr=eepi )

# %%
plot_monitor_var( 'evnum',"evnum",np.linspace(0,1.5e8,100), run=6421, df_dict_arr=eepi_pass_cuts )
plot_monitor_var( 'evnum',"evnum",np.linspace(0,1.5e8,100), run=6422, df_dict_arr=eepi_pass_cuts )
plot_monitor_var( 'evnum',"evnum",np.linspace(0,1.5e8,100), run=6426, df_dict_arr=eepi_pass_cuts )
plot_monitor_var( 'evnum',"evnum",np.linspace(0,1.5e8,100), run=6429, df_dict_arr=eepi_pass_cuts )

# %% [markdown]
# # Split cuts and check if we can learn why and at which cut we loose events

# %%
eepi_p_theta_cut = dict()
for subdirname in subdirnames:
    print(subdirname)
    print('-------------')
    eepi_p_theta_cut[subdirname] = apply_p_theta_acceptance_cut( eepi[subdirname] )
    
    print()
    
print('done.')
# Out:
# July_29_commit_338982b
# -------------
# Apply a π+/π- acceptance matching cut on the in p-theta plane
# Applying p-theta on cut for piplus on 1527104 events
# Subdividing into 3 subsets up to 500000 events
# Applying p-theta on cut for piminus on 682118 events
# Subdividing into 1 subsets up to 500000 events
#
# Sep_14_Wcut0.5_commit_869e7a8
# -------------
# Apply a π+/π- acceptance matching cut on the in p-theta plane
# Applying p-theta on cut for piplus on 2245132 events
# Subdividing into 4 subsets up to 500000 events
# Applying p-theta on cut for piminus on 1004797 events
# Subdividing into 2 subsets up to 500000 events
#
# Sep_14_Wcut2.5_commit_741b80a
# -------------
# Apply a π+/π- acceptance matching cut on the in p-theta plane
# Applying p-theta on cut for piplus on 1490417 events
# Subdividing into 2 subsets up to 500000 events
# Applying p-theta on cut for piminus on 626765 events
# Subdividing into 1 subsets up to 500000 events
#
# done.

# %%
plot_monitor_var( 'evnum',"evnum",np.linspace(0,1.5e8,100), run=6421, df_dict_arr=eepi_p_theta_cut )
plot_monitor_var( 'evnum',"evnum",np.linspace(0,1.5e8,100), run=6422, df_dict_arr=eepi_p_theta_cut )
plot_monitor_var( 'evnum',"evnum",np.linspace(0,1.5e8,100), run=6426, df_dict_arr=eepi_p_theta_cut )
plot_monitor_var( 'evnum',"evnum",np.linspace(0,1.5e8,100), run=6429, df_dict_arr=eepi_p_theta_cut )

# %%
# ----------------------- #
def apply_p_theta_acceptance_cut_single_set( df_dict=None,
                                 NeventsMax=-1,
                                 NMaxPerSubset = 500000,
                                 fdebug=1):
    '''
        df_dict_after_cut = apply_p_theta_acceptance_cut(df_dict)
        
        Apply a π+/π- acceptance matching cut on the in p-\theta plane
        last update Sep-15, 2022
        
    '''
    import numpy as np
    print("Apply a π+/π- acceptance matching cut on the in p-theta plane")
    df_dict_after_cut = dict()
        
    for pi_ch in pi_charge_names:
        
        if NeventsMax > 0: NeventsMax = np.min( [NeventsMax, len(df_dict[pi_ch])] )
        else:              NeventsMax = len(df_dict[pi_ch])
        df = df_dict[pi_ch][0:NeventsMax]
        if fdebug: print('Applying p-theta on cut for '+pi_ch+' on %d events'%NeventsMax)
        good_indices = np.array([])
        for sector in range(1,7):#{
            df_in_sector   = df[df.pi_DC_sector == sector]
            theta_min_pi   = pi_min_theta_cut( pi_charge = 'any', sector=sector, p=np.array(df_in_sector.pi_P) )
            good_indices_in_sector = []
            good_indices_in_sector = df_in_sector[ df_in_sector.pi_Theta*r2d > theta_min_pi ].index
            good_indices = np.concatenate([good_indices,good_indices_in_sector])
        #}
        good_indices = np.unique(good_indices)
        df_after_cut = df.loc[good_indices]

        df_dict_after_cut[pi_ch] = df_after_cut
    return df_dict_after_cut
# ----------------------- #

# %%
eepi_p_theta_cut_modified = dict()
for subdirname in subdirnames:
    print(subdirname)
    print('-------------')
    eepi_p_theta_cut_modified[subdirname] = apply_p_theta_acceptance_cut_single_set( eepi[subdirname],NeventsMax=-1 )    
    print()    
print('done.')
# Out:
# July_29_commit_338982b
# -------------
# Apply a π+/π- acceptance matching cut on the in p-theta plane
# Applying p-theta on cut for piplus on 1527104 events
# Applying p-theta on cut for piminus on 682118 events
#
# Sep_14_Wcut0.5_commit_869e7a8
# -------------
# Apply a π+/π- acceptance matching cut on the in p-theta plane
# Applying p-theta on cut for piplus on 2245132 events
# Applying p-theta on cut for piminus on 1004797 events
#
# Sep_14_Wcut2.5_commit_741b80a
# -------------
# Apply a π+/π- acceptance matching cut on the in p-theta plane
# Applying p-theta on cut for piplus on 1490417 events
# Applying p-theta on cut for piminus on 626765 events
#
# done.

# %%
plot_monitor_var( 'evnum',"evnum",np.linspace(0,1.5e8,100), run=6421, df_dict_arr=eepi_p_theta_cut_modified )
plot_monitor_var( 'evnum',"evnum",np.linspace(0,1.5e8,100), run=6422, df_dict_arr=eepi_p_theta_cut_modified )
plot_monitor_var( 'evnum',"evnum",np.linspace(0,1.5e8,100), run=6426, df_dict_arr=eepi_p_theta_cut_modified )
plot_monitor_var( 'evnum',"evnum",np.linspace(0,1.5e8,100), run=6429, df_dict_arr=eepi_p_theta_cut_modified )

# %% [markdown]
# # What is the difference between the data sets specifically for $W>2.5$ GeV ?

# %%
for subdirname,subdirlabel,subdircolor in zip(subdirnames,subdirlabels,subdircolors):
    print(subdirlabel)
    for pi_ch in pi_charge_names:
        # df = df_dict[pi_ch]
        df = eepi_pass_cuts[subdirname][pi_ch]        
        print(len(df),pi_ch,'events with W>%.1f'%np.min(df.W),'GeV/c2')
    print()
# Out:
# July-29,338982b
# 286985 piplus events with W>2.9 GeV/c2
# 172302 piminus events with W>2.9 GeV/c2
#
# Sep-14, W>0.5, 869e7a8
# 225520 piplus events with W>2.5 GeV/c2
# 157543 piminus events with W>2.5 GeV/c2
#
# Sep-14,W>2.5, 741b80a
# 261536 piplus events with W>2.5 GeV/c2
# 157543 piminus events with W>2.5 GeV/c2
