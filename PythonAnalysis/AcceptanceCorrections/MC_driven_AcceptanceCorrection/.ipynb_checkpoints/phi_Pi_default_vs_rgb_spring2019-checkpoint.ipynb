# %% [markdown]
# # Look at $\phi_\pi$ in default vs. rgb spring2019 GEMC (gcard) configurations
#
# last edit May-12, 2021

# %% [markdown]
# ## Imports and definitions

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, matplotlib as mpl
import sys; sys.path.insert(0, '/Users/erezcohen/Desktop/Software/mySoftware/Python/'); 
import sys; sys.path.insert(0, '/Users/erezcohen/Desktop/Software/CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/AcceptanceCorrections/'); 
from my_tools                     import *; 
from plot_tools                   import *;
from my_data_analysis_tools       import *;
from acceptance_correction_tools  import *;
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'

# %% [markdown]
# ## Auxiliary functions

# %% [markdown]
# # load data

# %%
main_data_path = '/Users/erezcohen/Desktop/data/BAND/AcceptanceCorrection/GEMCimulationOuputFiles/'

# %%
pips = dict()
labels = ['default'  ,'rgb_spring2019'];
colors = ['royalblue','salmon']
for i,label in zip(range(2),labels):
    pips[labels[i]] = pd.read_csv(main_data_path + 'gcard_' + label + '/'+ 
                                  'eepips_p_uniform_distribution.csv');
print('done')

# %% [markdown]
# ## plot $\phi_\pi$

# %%
fig = plt.figure(figsize=(8,6));
ax = fig.add_subplot(1,1,1)

for i,label,color in zip(range(2),labels,colors):
    df=pips[label]
    df = df[(df.e_reconstructed==1) & (df.pi_reconstructed==1)]

    plot_step_hist( x_arr=df.pi_Phi*r2d,  bins=phi_bins , label=label, 
                                                   color=color, 
                                                   do_plot_errorbar=False, density=False, linewidth=3)



    # cosmetics
    set_axes(ax, '$\phi$ [deg.]', 'Counts',
                 title='$\phi_\pi$ in different GEMC configurations',
                 do_add_grid=True,
                 do_add_legend=True,
                 xlim=phi_xlim,
                 xticks=phi_xticks)

# %%
df=pips[labels[i]]#.pi_Phi
df = df[(df.e_reconstructed==1) & (df.pi_reconstructed==1)]
df
# Out:
#           e_P   e_Theta     e_Phi      e_Vz      pi_P  pi_Theta    pi_Phi  \
# 2    1.348202  0.609202 -1.979073  7.786495  3.173409  0.276779  2.085634
# 3    1.023983  0.663922 -1.990114  8.859042  1.288816  0.466853  2.855617
# 4    1.348127  0.320975 -0.834098  7.243574  1.681863  0.428736 -1.418438
# 5    0.911350  0.460837  0.158490  7.752016  4.659974  0.454091 -0.294204
# 7    1.355463  0.564666 -0.731839  8.211624  2.292912  0.600479  2.477724
# ..        ...       ...       ...       ...       ...       ...       ...
# 979  1.341370  0.424007  0.351757  7.654179  1.294513  0.628245 -1.062786
# 980  1.346060  0.668036 -0.071510  7.337275  3.194769  0.501219 -2.387760
# 986  1.349898  0.363238 -0.342803  5.963978  3.719304  0.473646  0.891253
# 990  1.339486  0.573231 -2.165694  7.421594  4.946511  0.520887  2.453813
# 999  1.348983  0.452381  1.194872  7.436290  1.517846  0.581380 -3.117345
#
#          pi_Vz  Npips  Npims  ...  pi_passed_cuts  pi_passed_fiducial_cuts  \
# 2     6.674069    1.0    0.0  ...             1.0                      1.0
# 3     7.683556    1.0    0.0  ...             1.0                      1.0
# 4    12.290740    1.0    0.0  ...             1.0                      1.0
# 5     7.939155    1.0    0.0  ...             1.0                      1.0
# 7     8.414357    1.0    0.0  ...             1.0                      1.0
# ..         ...    ...    ...  ...             ...                      ...
# 979   7.815387    1.0    0.0  ...             1.0                      1.0
# 980   7.234007    1.0    0.0  ...             1.0                      1.0
# 986   8.116044    1.0    0.0  ...             1.0                      1.0
# 990   9.306935    1.0    0.0  ...             1.0                      1.0
# 999   8.300284    1.0    0.0  ...             1.0                      1.0
#
#      pi_passed_PID_cuts  e_reconstructed  e_passed_cuts  e_DC_sector  \
# 2                   1.0              1.0            1.0          5.0
# 3                   1.0              1.0            1.0          5.0
# 4                   1.0              1.0            1.0          6.0
# 5                   1.0              1.0            1.0          1.0
# 7                   1.0              1.0            1.0          6.0
# ..                  ...              ...            ...          ...
# 979                 1.0              1.0            1.0          1.0
# 980                 1.0              1.0            1.0          1.0
# 986                 1.0              1.0            0.0          6.0
# 990                 1.0              1.0            0.0          5.0
# 999                 1.0              1.0            1.0          2.0
#
#      pi_DC_sector       M_X  eepiPastKinematicalCuts  Unnamed: 33
# 2             3.0  4.469290                      1.0          NaN
# 3             4.0  5.137366                      0.0          NaN
# 4             6.0  5.091637                      1.0          NaN
# 5             1.0  3.073732                      1.0          NaN
# 7             4.0  4.393931                      1.0          NaN
# ..            ...       ...                      ...          ...
# 979           6.0  5.006674                      0.0          NaN
# 980           5.0  3.898376                      0.0          NaN
# 986           2.0  3.705285                      1.0          NaN
# 990           3.0  2.086457                      1.0          NaN
# 999           4.0  4.944997                      1.0          NaN
#
# [395 rows x 34 columns]
