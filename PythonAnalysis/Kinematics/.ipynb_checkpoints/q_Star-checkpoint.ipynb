# %% [markdown]
# # Study $q^*$ behaviour
# last edit Oct-18, 2022

# %% [markdown]
# ## Imports and definitions

# %%
import sys; 
software_path = '/Users/erezcohen/Desktop/Software/'
sys.path.insert(0, software_path + '/mySoftware/Python/');
sys.path.insert(0, software_path + '/CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/AcceptanceCorrections/');
sys.path.insert(0, software_path + '/CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/');
from my_tools                     import *; 
from plot_tools                   import *;
from my_data_analysis_tools       import *;
from acceptance_correction_tools  import *;
from sidis_analysis_tools         import *;
# from event_selection_tools        import *;

# %%
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['mathtext.fontset']    = 'stix'
plt.rcParams['font.family']         = 'STIXGeneral'

# %% [markdown]
# # (1) Load data:
# All runs of $(e,e'\pi)$ data and all runs of $(e,e'\pi n)$ - as with a small number of runs normalization is off

# %%
load_SIDIS_data( Nruns          = 1, 
                subdirname      = "sidisdvcs_v18Oct2022_commit_574cf9b",
                do_e_e_pi       = True, 
                do_e_e_pi_n     = False, 
                do_e_e_pi_FreeP = False, 
                do_all_vars     = True)
e_e_pi_pass_cuts,_,_,_ = apply_further_selection_cuts_to_data(fdebug=0);
# Out:
# Run number  6421 (1/1 runs)
# Loaded 361449  d(e,e'π+) events
# Loaded 152457  d(e,e'π-) events
# Done loading files.
#
# Total statistics:
# 361449  d(e,e'π+)  events
# 152457  d(e,e'π-)  events
# Applying selection cuts not previously imposed
# Apply a π+/π- acceptance matching cut on the in p-theta plane
# Apply a cut on the missing mass of a (e,e'π) reaction: 1.3<Mx<5.0 GeV/c2
# (e,e π+ )
# 361449 events after original cut (100.0 %)
# 245350 events after p-theta cut (67.9 %)
# 232178 events after Mx cut (64.2 %)
# 232178 events after Kinematical cut (64.2 %)
# (e,e π- )
# 152457 events after original cut (100.0 %)
# 147669 events after p-theta cut (96.9 %)
# 142023 events after Mx cut (93.2 %)
# 142023 events after Kinematical cut (93.2 %)
#
# Done applying event-selection cuts

# %% [markdown]
# # (2) plot $q^*$

# %%
var,varlabel,varunits,bins = "qStar","$q^*$","[GeV/c]",np.linspace(-7,7,50)
xticks = None; #(2,4,6)
fig = plt.figure(figsize=(12,6),tight_layout=True)
ax = fig.add_subplot(1,1,1)
for pi_ch,pi_print,pi_label,pi_color,pi_idx in zip(pi_charge_names,pi_prints,
                                                   pi_labels,pi_colors,[1,2]):    
    df = e_e_pi_pass_cuts[pi_ch]
    [x,
     h['untagged'+pi_ch],
     x_err,
     h_err['untagged'+pi_ch]] = plot_step_squares(df[var], 
                                                  ax=ax,                                                    
                                                  bins=bins,                                                   
                                                  density=True,                                                   
                                                  color=pi_color,                                                   
                                                  alpha=0.5,                                                   
                                                  label="$d(e,e'"+pi_print+")$" )
    ax.step(x,h['untagged'+pi_ch],'-',where='mid', color=pi_color )

set_axes(ax,varlabel + " " + varunits,
             'Frequency [a.u.]', 
             title="Novel SIDIS observable $q^* = −\sin \phi_\pi \;\\frac{p_\pi^\perp}{z}$",
             do_add_grid=True, do_add_legend=True,
             xticks=xticks);

# %% [markdown]
# # (3) Subdivide contributions of different $q^*$ consistuents

# %%
Nbins = 50
fig = plt.figure(figsize=(12,12),tight_layout=True)

for [var,
     varlabel,
     varunits,
     varfunction,
     bins,
     v_idx] in zip(["Zpi",    "pi_qFrame_pT", "pi_qFrame_Phi"],                                      
                   ["$z_\pi$","$p^\perp_\pi$","$\sin\phi_\pi$"],
                   ["",       "[GeV/c]",      ""],
                   ['',       '',             "sin"],
                   [np.linspace(0.3,0.9,Nbins),                   
                    np.linspace(0.0,1.2,Nbins),                    
                    np.linspace(-1,1,Nbins)],
                   [1,2,3]):

    xticks = None;
    ax = fig.add_subplot(3,1,v_idx);
    for pi_ch,pi_print,pi_label,pi_color,pi_idx in zip(pi_charge_names,pi_prints,
                                                       pi_labels,pi_colors,[1,2]):    
        df = e_e_pi_pass_cuts[pi_ch]
        if varfunction is "sin":
            step_results = plot_step_squares(np.sin(df[var]),
                                                      ax=ax,                                                    
                                                      bins=bins,                                                   
                                                      density=True,                                                   
                                                      color=pi_color,                                                   
                                                      alpha=0.5,                                                   
                                                      label="$d(e,e'"+pi_print+")$" )

        else:
            step_results = plot_step_squares(df[var], 
                                                      ax=ax,                                                    
                                                      bins=bins,                                                   
                                                      density=True,                                                   
                                                      color=pi_color,                                                   
                                                      alpha=0.5,                                                   
                                                      label="$d(e,e'"+pi_print+")$" )
        
        [x, h['untagged'+pi_ch], x_err, h_err['untagged'+pi_ch]] = step_results        
        ax.step(x,h['untagged'+pi_ch],'-',where='mid', color=pi_color )

    set_axes(ax,varlabel + " " + varunits,
                 '', remove_ticks_y=True,
                 do_add_grid=True, 
             do_add_legend=True if v_idx==1 else False,
                 xticks=xticks);
# Out:
# <>:23: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:23: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /var/folders/42/n5_htl9n34j9wpgd5rqsnmv40000gn/T/ipykernel_77079/3845285513.py:23: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if varfunction is "sin":
