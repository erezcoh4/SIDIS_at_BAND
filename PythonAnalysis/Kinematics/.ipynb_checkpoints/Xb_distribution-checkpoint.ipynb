# %% [markdown]
# # Plot $x_B$ distribution of tagged and untagged events
# With background subtraction of tagged events, based on ToF
#
# last edit July-7, 2022

# %% [markdown]
# ## Imports and definitions

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, matplotlib as mpl
import sys; 
sys.path.insert(0, '/Users/erezcohen/Desktop/Software/mySoftware/Python/'); 
sys.path.insert(0, '/Users/erezcohen/Desktop/Software/CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/AcceptanceCorrections/'); 
from my_tools                     import *; 
from plot_tools                   import *;
from my_data_analysis_tools       import *;
from acceptance_correction_tools  import *;
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['mathtext.fontset']    = 'stix'
plt.rcParams['font.family']         = 'STIXGeneral'

# %% [markdown]
# ## (1) Load data

# %%
load_SIDIS_data( Nruns = 101, do_e_e_pi=False )
# Out:
# Run number  6421 (1/86 runs)
# Loaded 56  (e,e'π+n) events
# Loaded 23  (e,e'π-n) events
# Run number  6422 (2/86 runs)
# Loaded 81  (e,e'π+n) events
# Loaded 29  (e,e'π-n) events
# Run number  6426 (3/86 runs)
# Loaded 32  (e,e'π+n) events
# Loaded 14  (e,e'π-n) events
# Run number  6429 (4/86 runs)
# Loaded 77  (e,e'π+n) events
# Loaded 18  (e,e'π-n) events
# Run number  6430 (5/86 runs)
# Loaded 8  (e,e'π+n) events
# Loaded 4  (e,e'π-n) events
# Run number  6431 (6/86 runs)
# Loaded 77  (e,e'π+n) events
# Loaded 19  (e,e'π-n) events
# Run number  6432 (7/86 runs)
# Loaded 70  (e,e'π+n) events
# Loaded 26  (e,e'π-n) events
# Run number  6433 (8/86 runs)
# Loaded 83  (e,e'π+n) events
# Loaded 20  (e,e'π-n) events
# Run number  6437 (9/86 runs)
# Loaded 23  (e,e'π+n) events
# Loaded 10  (e,e'π-n) events
# Run number  6442 (10/86 runs)
# Loaded 87  (e,e'π+n) events
# Loaded 28  (e,e'π-n) events
# Run number  6444 (11/86 runs)
# Loaded 12  (e,e'π+n) events
# Loaded 4  (e,e'π-n) events
# Run number  6445 (12/86 runs)
# Loaded 92  (e,e'π+n) events
# Loaded 25  (e,e'π-n) events
# Run number  6449 (13/86 runs)
# Loaded 66  (e,e'π+n) events
# Loaded 15  (e,e'π-n) events
# Run number  6450 (14/86 runs)
# Loaded 58  (e,e'π+n) events
# Loaded 28  (e,e'π-n) events
# Run number  6451 (15/86 runs)
# Loaded 65  (e,e'π+n) events
# Loaded 20  (e,e'π-n) events
# Run number  6452 (16/86 runs)
# Loaded 82  (e,e'π+n) events
# Loaded 22  (e,e'π-n) events
# Run number  6453 (17/86 runs)
# Loaded 65  (e,e'π+n) events
# Loaded 23  (e,e'π-n) events
# Run number  6454 (18/86 runs)
# Loaded 28  (e,e'π+n) events
# Loaded 15  (e,e'π-n) events
# Run number  6455 (19/86 runs)
# Loaded 72  (e,e'π+n) events
# Loaded 14  (e,e'π-n) events
# Run number  6456 (20/86 runs)
# Loaded 58  (e,e'π+n) events
# Loaded 27  (e,e'π-n) events
# Run number  6457 (21/86 runs)
# Loaded 23  (e,e'π+n) events
# Loaded 4  (e,e'π-n) events
# Run number  6461 (22/86 runs)
# Loaded 90  (e,e'π+n) events
# Loaded 27  (e,e'π-n) events
# Run number  6462 (23/86 runs)
# Loaded 99  (e,e'π+n) events
# Loaded 26  (e,e'π-n) events
# Run number  6463 (24/86 runs)
# Loaded 66  (e,e'π+n) events
# Loaded 21  (e,e'π-n) events
# Run number  6464 (25/86 runs)
# Loaded 27  (e,e'π+n) events
# Loaded 5  (e,e'π-n) events
# Run number  6465 (26/86 runs)
# Loaded 72  (e,e'π+n) events
# Loaded 21  (e,e'π-n) events
# Run number  6466 (27/86 runs)
# Loaded 78  (e,e'π+n) events
# Loaded 25  (e,e'π-n) events
# Run number  6467 (28/86 runs)
# Loaded 73  (e,e'π+n) events
# Loaded 16  (e,e'π-n) events
# Run number  6468 (29/86 runs)
# Loaded 25  (e,e'π+n) events
# Loaded 6  (e,e'π-n) events
# Run number  6470 (30/86 runs)
# Loaded 43  (e,e'π+n) events
# Loaded 11  (e,e'π-n) events
# Run number  6472 (31/86 runs)
# Loaded 70  (e,e'π+n) events
# Loaded 21  (e,e'π-n) events
# Run number  6473 (32/86 runs)
# Loaded 19  (e,e'π+n) events
# Loaded 12  (e,e'π-n) events
# Run number  6474 (33/86 runs)
# Loaded 78  (e,e'π+n) events
# Loaded 14  (e,e'π-n) events
# Run number  6475 (34/86 runs)
# Loaded 71  (e,e'π+n) events
# Loaded 21  (e,e'π-n) events
# Run number  6476 (35/86 runs)
# Loaded 42  (e,e'π+n) events
# Loaded 9  (e,e'π-n) events
# Run number  6479 (36/86 runs)
# Loaded 75  (e,e'π+n) events
# Loaded 26  (e,e'π-n) events
# Run number  6481 (37/86 runs)
# Loaded 96  (e,e'π+n) events
# Loaded 24  (e,e'π-n) events
# Run number  6482 (38/86 runs)
# Loaded 73  (e,e'π+n) events
# Loaded 16  (e,e'π-n) events
# Run number  6483 (39/86 runs)
# Loaded 52  (e,e'π+n) events
# Loaded 14  (e,e'π-n) events
# Run number  6484 (40/86 runs)
# Loaded 74  (e,e'π+n) events
# Loaded 24  (e,e'π-n) events
# Run number  6485 (41/86 runs)
# Loaded 30  (e,e'π+n) events
# Loaded 12  (e,e'π-n) events
# Run number  6486 (42/86 runs)
# Loaded 84  (e,e'π+n) events
# Loaded 18  (e,e'π-n) events
# Run number  6488 (43/86 runs)
# Loaded 72  (e,e'π+n) events
# Loaded 13  (e,e'π-n) events
# Run number  6489 (44/86 runs)
# Loaded 72  (e,e'π+n) events
# Loaded 12  (e,e'π-n) events
# Run number  6491 (45/86 runs)
# Loaded 99  (e,e'π+n) events
# Loaded 30  (e,e'π-n) events
# Run number  6498 (46/86 runs)
# Loaded 69  (e,e'π+n) events
# Loaded 17  (e,e'π-n) events
# Run number  6499 (47/86 runs)
# Loaded 78  (e,e'π+n) events
# Loaded 15  (e,e'π-n) events
# Run number  6502 (48/86 runs)
# Loaded 98  (e,e'π+n) events
# Loaded 22  (e,e'π-n) events
# Run number  6510 (49/86 runs)
# Loaded 35  (e,e'π+n) events
# Loaded 9  (e,e'π-n) events
# Run number  6511 (50/86 runs)
# Loaded 48  (e,e'π+n) events
# Loaded 8  (e,e'π-n) events
# Run number  6512 (51/86 runs)
# Loaded 90  (e,e'π+n) events
# Loaded 16  (e,e'π-n) events
# Run number  6513 (52/86 runs)
# Loaded 71  (e,e'π+n) events
# Loaded 26  (e,e'π-n) events
# Run number  6514 (53/86 runs)
# Loaded 66  (e,e'π+n) events
# Loaded 33  (e,e'π-n) events
# Run number  6522 (54/86 runs)
# Loaded 61  (e,e'π+n) events
# Loaded 13  (e,e'π-n) events
# Run number  6523 (55/86 runs)
# Loaded 57  (e,e'π+n) events
# Loaded 14  (e,e'π-n) events
# Run number  6524 (56/86 runs)
# Loaded 95  (e,e'π+n) events
# Loaded 23  (e,e'π-n) events
# Run number  6525 (57/86 runs)
# Loaded 68  (e,e'π+n) events
# Loaded 16  (e,e'π-n) events
# Run number  6546 (58/86 runs)
# Loaded 43  (e,e'π+n) events
# Loaded 17  (e,e'π-n) events
# Run number  6547 (59/86 runs)
# Loaded 43  (e,e'π+n) events
# Loaded 11  (e,e'π-n) events
# Run number  6548 (60/86 runs)
# Loaded 42  (e,e'π+n) events
# Loaded 21  (e,e'π-n) events
# Run number  6549 (61/86 runs)
# Loaded 47  (e,e'π+n) events
# Loaded 10  (e,e'π-n) events
# Run number  6550 (62/86 runs)
# Loaded 44  (e,e'π+n) events
# Loaded 17  (e,e'π-n) events
# Run number  6557 (63/86 runs)
# Loaded 50  (e,e'π+n) events
# Loaded 13  (e,e'π-n) events
# Run number  6559 (64/86 runs)
# Loaded 44  (e,e'π+n) events
# Loaded 17  (e,e'π-n) events
# Run number  6560 (65/86 runs)
# Loaded 17  (e,e'π+n) events
# Loaded 6  (e,e'π-n) events
# Run number  6563 (66/86 runs)
# Loaded 18  (e,e'π+n) events
# Loaded 0  (e,e'π-n) events
# Run number  6565 (67/86 runs)
# Loaded 33  (e,e'π+n) events
# Loaded 13  (e,e'π-n) events
# Run number  6566 (68/86 runs)
# Loaded 38  (e,e'π+n) events
# Loaded 9  (e,e'π-n) events
# Run number  6567 (69/86 runs)
# Loaded 39  (e,e'π+n) events
# Loaded 19  (e,e'π-n) events
# Run number  6569 (70/86 runs)
# Loaded 55  (e,e'π+n) events
# Loaded 9  (e,e'π-n) events
# Run number  6570 (71/86 runs)
# Loaded 48  (e,e'π+n) events
# Loaded 10  (e,e'π-n) events
# Run number  6571 (72/86 runs)
# Loaded 43  (e,e'π+n) events
# Loaded 13  (e,e'π-n) events
# Run number  6572 (73/86 runs)
# Loaded 36  (e,e'π+n) events
# Loaded 17  (e,e'π-n) events
# Run number  6576 (74/86 runs)
# Loaded 46  (e,e'π+n) events
# Loaded 18  (e,e'π-n) events
# Run number  6577 (75/86 runs)
# Loaded 41  (e,e'π+n) events
# Loaded 16  (e,e'π-n) events
# Run number  6578 (76/86 runs)
# Loaded 31  (e,e'π+n) events
# Loaded 7  (e,e'π-n) events
# Run number  6582 (77/86 runs)
# Loaded 20  (e,e'π+n) events
# Loaded 4  (e,e'π-n) events
# Run number  6585 (78/86 runs)
# Loaded 32  (e,e'π+n) events
# Loaded 4  (e,e'π-n) events
# Run number  6586 (79/86 runs)
# Loaded 35  (e,e'π+n) events
# Loaded 12  (e,e'π-n) events
# Run number  6587 (80/86 runs)
# Loaded 28  (e,e'π+n) events
# Loaded 3  (e,e'π-n) events
# Run number  6589 (81/86 runs)
# Loaded 7  (e,e'π+n) events
# Loaded 2  (e,e'π-n) events
# Run number  6590 (82/86 runs)
# Loaded 63  (e,e'π+n) events
# Loaded 15  (e,e'π-n) events
# Run number  6591 (83/86 runs)
# Loaded 50  (e,e'π+n) events
# Loaded 9  (e,e'π-n) events
# Run number  6593 (84/86 runs)
# Loaded 32  (e,e'π+n) events
# Loaded 6  (e,e'π-n) events
# Run number  6595 (85/86 runs)
# Loaded 38  (e,e'π+n) events
# Loaded 17  (e,e'π-n) events
# Run number  6597 (86/86 runs)
# Loaded 28  (e,e'π+n) events
# Loaded 0  (e,e'π-n) events
# Done loading files.
#
# Total statistics:
# 4722  (e,e'π+n) events
# 1339  (e,e'π-n) events

# %% [markdown]
# ## (2) Apply selection cuts not previously imposed
# without the cut on $p_n > 0.275$ GeV/c

# %%
e_e_pi_pass_cuts,e_e_pi_n_pass_cuts,_ = apply_further_selection_cuts_to_data(doApply_minPn_cut=False, 
                                                                             fdebug=2, 
                                                                             NeventsMax=-1);
# Out:
# Applying selection cuts not previously imposed
# (1) DATA
# (e,e'π)
# Apply a π+/π- acceptance matching cut on the in p-theta plane
# applying p-theta cut only to 1234060 events
# Apply a cut on the missing mass of a (e,e'π) reaction: 2.5<Mx<5.0 GeV/c2
# (e,e π+ )
# 1234060 events before cut
# 1107517 events after p-theta cut (89.7 %)
# 1019530 events after M_X cut (82.6 %)
# (e,e π- )
# 529918 events before cut
# 528933 events after p-theta cut (99.8 %)
# 489627 events after M_X cut (92.4 %)
#
# (e,e'πn)
# Apply a π+/π- acceptance matching cut on the in p-theta plane
# applying p-theta cut only to 4722 events
# (e,e π+ )
# 4722 events before cut
# 4722 events after min p(n) cut (100.0 %)
# 4716 events after p-theta cut (99.9 %)
# (e,e π- )
# 1339 events before cut
# 1339 events after min p(n) cut (100.0 %)
# 1339 events after p-theta cut (100.0 %)
#
# Done applying selection cuts not previously imposed

# %% [markdown]
# ## (3) Subdivide into bins of $x_B$ and plot $E_n$ distribution in each bin to estimate background
# $ x_B = Q^2/2m_p\omega$

# %%
np.min(e_e_pi_n_pass_cuts['piplus'].n_P)
# Out:
# 0.248321982

# %% [markdown]
# ## (3.1) first plot $x_B$ distribution to choose binning

# %%
fig = plt.figure(figsize=(9,6))
ax = fig.add_subplot(1,1,1)
for pi_ch,pi_print,pi_label,pi_color in zip(pi_charge_names,pi_prints,pi_labels,pi_colors):
    df = e_e_pi_n_pass_cuts[pi_ch]
    plot_step_hist( df.xB, bins=np.linspace(0.1,0.6,20) , color=pi_color,label='$'+pi_label+'$')
set_axes(ax,'$x_B$','counts', title="$(e,e'\pi n)$ event distribution as a function of $x_B$", do_add_grid=True, do_add_legend=True)
plt.tight_layout()

# %%
bins = np.linspace(0.,0.7,20)
fig = plt.figure(figsize=(12,6))

for pi_ch,pi_print,pi_label,pi_color,pi_idx in zip(pi_charge_names,pi_prints,pi_labels,pi_colors,[1,2]):
    ax = fig.add_subplot(1,2,pi_idx)
    
    df = e_e_pi_pass_cuts[pi_ch]
    plot_step_hist( df.xB, bins=bins, marker='o', color=pi_color,label='untagged', alpha=1, density=True)

    df = e_e_pi_n_pass_cuts[pi_ch]
    plot_step_hist( df.xB, bins=bins, marker='s', color=pi_color,label='tagged', alpha=1, density=True)

    set_axes(ax,'$x_B$','Frequency [a.u.]', 
             title="$(e,e'"+pi_label+")$ events",
             do_add_grid=True, do_add_legend=True)
plt.tight_layout()

# %% [markdown]
# ## (3.2) now choose binning and plot $p_n$ distribution in each bin

# %%
x_bins   = np.linspace(0.2,0.5,6)
x        = (x_bins[1:] + x_bins[:-1])/2
x_err    = (x_bins[1:] - x_bins[:-1])/2
Nbins    = len(x_bins)
x_bins
# Out:
# array([0.2 , 0.26, 0.32, 0.38, 0.44, 0.5 ])

# %%
var_label = "standing proton x"
var    = 'xB'
xlabel = "Bjorken $x$"

# %%
fig = plt.figure(figsize=(12,8))
pi_ch = 'piplus'
for bin_idx in range(Nbins):
    x_min, x_max  = x_bins[bin_idx] - x_err[1], x_bins[bin_idx] + x_err[1]
    # df = e_e_pi_pass_cuts[pi_ch];
    # eepi_in_bin   = df[ (x_min < df.xB ) & (df.xB < x_max )]

    df = e_e_pi_n_pass_cuts[pi_ch];
    eepi_n_in_bin = df[ (x_min < df.xB ) & (df.xB < x_max )]

    ax  = fig.add_subplot(2,Nbins/2,bin_idx+1)
    ax.hist( eepi_n_in_bin.n_P, bins=np.linspace(0.2,0.6,20) )
    set_axes(ax,'$p_n$ [GeV]','counts', title='$%.2f < x_B < %.2f$'%(x_min,x_max), xlim=(0.2,0.6),fontsize=16);

plt.tight_layout()

# Add two lines indicating the cut boundaries
# estimate background from distribution outside the cut region
# Out:
# /var/folders/42/n5_htl9n34j9wpgd5rqsnmv40000gn/T/ipykernel_44108/2570688738.py:11: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax  = fig.add_subplot(2,Nbins/2,bin_idx+1)

# %% [markdown]
# # (4) Save results to file

# %%
main_data_path = '/Users/erezcohen/Desktop/data/BAND/'
results_data_path = main_data_path + '/' + 'Results' + '/'
for z_bin,z_width in zip(z_bins,z_widths):
    y    = Rpips2pims[z_bin]
    y_err_up = Rpips2pims_errup[z_bin]
    y_err_dw = Rpips2pims_errdw[z_bin]
    df_to_save = pd.DataFrame({"$x_B$":x,"$\Delta x_B$":x_err,
                               '$R$':y,
                               '$\Delta R_{+}$':y_err_up,'$\Delta R_{-}$':y_err_dw})
    print('$z=%.2f\pm%.2f$'%(z_bin,z_width))
    filelabel = 'z_%.2f-%.2f'%(z_bin-z_width,z_bin+z_width)
    filename  =  results_data_path + 'Untagged_SIDIS_ratio_' + filelabel + '.csv'
    print(filename)
    
    display(df_to_save)
    # df_to_save.to_csv(filename)
    # print('saved',filename)
