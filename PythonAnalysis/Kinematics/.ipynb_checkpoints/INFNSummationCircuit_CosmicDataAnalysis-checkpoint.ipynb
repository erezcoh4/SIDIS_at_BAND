# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt

# %% [markdown]
# ## Imports and definitions

# %%
import sys; 
software_path = '/Users/erezcohen/Desktop/Software/'
sys.path.insert(0, software_path + '/mySoftware/Python/');
sys.path.insert(0, software_path + '/CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/AcceptanceCorrections/');
sys.path.insert(0, software_path + '/CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/');
from my_tools                     import *; 
from plot_tools                   import *;
from my_data_analysis_tools       import *;
from acceptance_correction_tools  import *;
from sidis_analysis_tools         import *;
# Out:
# Welcome to JupyROOT 6.26/06
# Loaded bin migration and acceptance weights from MC calculations.

# %%
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['mathtext.fontset']    = 'stix'
plt.rcParams['font.family']         = 'STIXGeneral'

# %% [markdown]
# # Load data

# %%
wf_id = 1
wf_c1 = pd.read_csv('/Users/erezcohen/Desktop/data/ScintillatorTimeResolution/INFN_Summation_Circuit/Sep2023_two_sides_cosmic/C1--erez22--%05d.csv'%wf_id,skiprows=4)
wf_c2 = pd.read_csv('/Users/erezcohen/Desktop/data/ScintillatorTimeResolution/INFN_Summation_Circuit/Sep2023_two_sides_cosmic/C2--erez22--%05d.csv'%wf_id,skiprows=4)

# %%
fig,ax = plt.subplots(figsize=(9,5))
plt.plot(wf_c1.Time*1e9, wf_c1.Ampl, label='Ch. 1')
plt.plot(wf_c2.Time*1e9, wf_c2.Ampl, label='Ch. 2')
set_axes(ax,'Time [ns]', 'Voltage [V]', title='Trigger number %d'%wf_id,do_add_grid=True,do_add_legend=True, fontsize=14);
