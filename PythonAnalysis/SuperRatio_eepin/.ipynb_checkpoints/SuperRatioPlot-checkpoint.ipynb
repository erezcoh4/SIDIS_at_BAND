# %% [markdown]
# # Super ratio of $(e,e'\pi^+)/(e,e'\pi^+)$ with a fast tagged neutron
#
# $$\left(\frac{\sigma(e,e'\pi^+)}{\sigma(e,e'\pi^+)}\right)_{p_n>275 GeV/c}/\left(\frac{\sigma(e,e'\pi^+)}{\sigma(e,e'\pi^+)}\right)$$
#
# last edit Dec-2, 2021

# %% [markdown]
# ## definitions

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, matplotlib as mpl
import sys; sys.path.insert(0, '/Users/erezcohen/Desktop/Software/mySoftware/Python/'); 
from my_tools               import *; 
from plot_tools             import *;
from my_data_analysis_tools import *;
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'
r2d = 180./np.pi

# %%
main_data_path     = '/Users/erezcohen/Desktop/data/BAND/'
e_e_pi_data_path   = main_data_path + 'SIDIS_skimming/'
e_e_pi_n_data_path = main_data_path + 'merged_SIDIS_and_BAND_skimming/'

# %%
pi_charge_names  = ['piplus'   ,'piminus'  ]
pi_labels        = ['\pi^{+}'  ,'\pi^{-}'  ]
pi_colors        = ['royalblue','salmon'   ]

# %% [markdown]
# ## load data

# %% [markdown]
# ## Selection cuts not previously imposed

# %%
# for pi_charge_name in pi_charge_names:
#     # large momentum neutrons ( Pn > 275 MeV/c)
#     e_e_pi_n[pi_charge_name] = e_e_pi_n[pi_charge_name][e_e_pi_n[pi_charge_name]['n_P']>0.275]
    
#     print('retained',len(e_e_pi_n[pi_charge_name]),'(e,e',pi_charge_name,'n), events')

# %% [markdown]
# ## Auxiliary functions

# %%
def plot_step_hist( df, var='xB',
                   bins=np.linspace(0,1,10), label="$(e,e')$"):
    h,edges = np.histogram( df[var], bins=x_bins)
    h_err = np.sqrt(h)
    x     = (edges[1:] + edges[:-1])/2
    x_err = (edges[1:] - edges[:-1])/2
    plt.step ( x, h, color=pi_color, where='mid', label=label ) 
    plt.errorbar ( x, h, h_err, color=pi_color, marker='o', linestyle='None',label=None, capsize=2 )
    return x,h,x_err

# %%
def get_err_up_dw(x, xerr,lim_dw = 0,lim_up = 10):
    errup=xerr
    errdw=xerr
    
    for i in range(len(x)):
        if (x[i]+errup[i]) > lim_up:
            errup[i] = lim_up-x[i]
        
        if lim_dw > (x[i]-errdw[i]):
            errdw[i] = x[i]-lim_dw
        

    return errup,errdw

# %%
def compute_ratio_pips_to_pims(df_dict, var='xB', bins=np.linspace(0,1,10), z_min=0, z_max=1, 
                               theta_min=0, theta_max=np.pi):
    # z_min,z_max are z limits on the pion outgoing momentum
    df_pips = df_dict['piplus']
    df_pims = df_dict['piminus']
    # cut on z
    df_pips = df_pips[ (z_min<df_pips.Zpi) & (df_pips.Zpi<z_max) & (theta_min<df_pips.pi_Theta*r2d) & (df_pips.pi_Theta*r2d<theta_max)]
    df_pims = df_pims[ (z_min<df_pims.Zpi) & (df_pims.Zpi<z_max) & (theta_min<df_pims.pi_Theta*r2d) & (df_pims.pi_Theta*r2d<theta_max) ]

    pips = df_pips[var]
    pims = df_pims[var]
    R_pips_to_pims, R_pips_to_pims_err = [],[]
    for x_min,x_max in zip(x_bins[:-1],x_bins[1:]):
        
        pips_in_bin  = pips[ (x_min < pips) & (pips < x_max) ]
        Npips_in_bin = len(pips_in_bin)
        pims_in_bin  = pims[ (x_min < pims) & (pims < x_max) ]
        Npims_in_bin = len(pims_in_bin)    

        R            = Npips_in_bin/np.max([Npims_in_bin,1])
        R_err        = R * np.sqrt( 1./np.max([1,Npips_in_bin]) + 1./np.max([1,Npims_in_bin]) )

        R_pips_to_pims    .append(R)
        R_pips_to_pims_err.append(R_err)
        
    R_pips_to_pims_errup,R_pips_to_pims_errdw = get_err_up_dw(R_pips_to_pims, R_pips_to_pims_err)
    
    return np.array(R_pips_to_pims),np.array(R_pips_to_pims_errup),np.array(R_pips_to_pims_errdw)

# %% [markdown]
# ## Super - ratio: the number of events in each sample

# %% [markdown]
# ### super ratio as a function of $x_B$

# %%
fontsize = 18

# %% [markdown]
# # Accumulated data from 101 runs of 10.2 GeV

# %% [markdown]
# ## load data

# %%
runs_filename = "/Users/erezcohen/Desktop/Software/CLAS12/BAND/SIDIS_at_BAND/macros/runlists/good_runs_10-2.txt"

# Using readlines()
runs_file     = open(runs_filename, 'r')
run_fileLines = runs_file.readlines()
runs = []
for line in run_fileLines:#{
    run = int(line.strip())
    runs.append(run)
runs = np.array(runs)
runs
# Out:
# array([6420, 6421, 6422, 6426, 6428, 6429, 6430, 6431, 6432, 6433, 6437,
#        6442, 6443, 6444, 6445, 6449, 6450, 6451, 6452, 6453, 6454, 6455,
#        6456, 6457, 6458, 6461, 6462, 6463, 6464, 6465, 6466, 6467, 6468,
#        6470, 6472, 6473, 6474, 6475, 6476, 6479, 6481, 6482, 6483, 6484,
#        6485, 6486, 6488, 6489, 6491, 6492, 6498, 6499, 6501, 6502, 6510,
#        6511, 6512, 6513, 6514, 6516, 6522, 6523, 6524, 6525, 6546, 6547,
#        6548, 6549, 6550, 6557, 6558, 6559, 6560, 6562, 6563, 6565, 6566,
#        6567, 6568, 6569, 6570, 6571, 6572, 6573, 6576, 6577, 6578, 6581,
#        6582, 6585, 6586, 6587, 6589, 6590, 6591, 6592, 6593, 6595, 6596,
#        6597, 6598])

# %%
e_e_pi = dict()
e_e_pi_n = dict()

# runs = [6420,6421,6422,6426]

for runnum,runIdx in zip(runs,range(len(runs))):
    for pi_charge_name in pi_charge_names:
        eepi   = pd.read_csv(e_e_pi_data_path 
                                           +'skimmed_SIDIS_inc_00%d_e_%s_selected_eepi_kinematics.csv'%(runnum,pi_charge_name))
        eepin = pd.read_csv(e_e_pi_n_data_path 
                                           +'skimmed_SIDIS_and_BAND_inc_00%d_e_%s_n.csv'%(runnum,pi_charge_name))        

        print('loaded',len(eepi),'(e,e',pi_charge_name,
              ') events and ',
              len(eepin),'(e,e',pi_charge_name,'n), events')    
    
        # large momentum neutrons ( Pn > 275 MeV/c)
        eepin = eepin[eepin['n_P']>0.275]
        # print('retained',len(eepin),'(e,e',pi_charge_name,'n), events')            
        
        if runIdx==0:             
            e_e_pi[pi_charge_name]   = eepi
            e_e_pi_n[pi_charge_name] = eepin
        else:
            e_e_pi[pi_charge_name]   = pd.concat([e_e_pi[pi_charge_name],  eepi ])
            e_e_pi_n[pi_charge_name] = pd.concat([e_e_pi_n[pi_charge_name],eepin])
    print('%d/%d'%(runIdx,len(runs)))
# Out:
# loaded 457235 (e,e piplus ) events and  48 (e,e piplus n), events
# loaded 187621 (e,e piminus ) events and  7 (e,e piminus n), events
# 0/101
# loaded 448079 (e,e piplus ) events and  35 (e,e piplus n), events
# loaded 186637 (e,e piminus ) events and  12 (e,e piminus n), events
# 1/101
# loaded 427456 (e,e piplus ) events and  57 (e,e piplus n), events
# loaded 175964 (e,e piminus ) events and  15 (e,e piminus n), events
# 2/101
# loaded 379753 (e,e piplus ) events and  27 (e,e piplus n), events
# loaded 157153 (e,e piminus ) events and  12 (e,e piminus n), events
# 3/101
# loaded 475947 (e,e piplus ) events and  40 (e,e piplus n), events
# loaded 197932 (e,e piminus ) events and  18 (e,e piminus n), events
# 4/101
# loaded 479264 (e,e piplus ) events and  56 (e,e piplus n), events
# loaded 197887 (e,e piminus ) events and  14 (e,e piminus n), events
# 5/101
# loaded 92035 (e,e piplus ) events and  6 (e,e piplus n), events
# loaded 38004 (e,e piminus ) events and  3 (e,e piminus n), events
# 6/101
# loaded 375138 (e,e piplus ) events and  46 (e,e piplus n), events
# loaded 154993 (e,e piminus ) events and  7 (e,e piminus n), events
# 7/101
# loaded 466968 (e,e piplus ) events and  50 (e,e piplus n), events
# loaded 193352 (e,e piminus ) events and  17 (e,e piminus n), events
# 8/101
# loaded 525505 (e,e piplus ) events and  54 (e,e piplus n), events
# loaded 215118 (e,e piminus ) events and  10 (e,e piminus n), events
# 9/101
# loaded 158412 (e,e piplus ) events and  17 (e,e piplus n), events
# loaded 65335 (e,e piminus ) events and  4 (e,e piminus n), events
# 10/101
# loaded 429355 (e,e piplus ) events and  42 (e,e piplus n), events
# loaded 177849 (e,e piminus ) events and  17 (e,e piminus n), events
# 11/101
# loaded 407903 (e,e piplus ) events and  39 (e,e piplus n), events
# loaded 168222 (e,e piminus ) events and  10 (e,e piminus n), events
# 12/101
# loaded 77244 (e,e piplus ) events and  6 (e,e piplus n), events
# loaded 32046 (e,e piminus ) events and  3 (e,e piminus n), events
# 13/101
# loaded 395303 (e,e piplus ) events and  52 (e,e piplus n), events
# loaded 163268 (e,e piminus ) events and  16 (e,e piminus n), events
# 14/101
# loaded 449949 (e,e piplus ) events and  50 (e,e piplus n), events
# loaded 184351 (e,e piminus ) events and  12 (e,e piminus n), events
# 15/101
# loaded 464508 (e,e piplus ) events and  40 (e,e piplus n), events
# loaded 190309 (e,e piminus ) events and  19 (e,e piminus n), events
# 16/101
# loaded 461733 (e,e piplus ) events and  41 (e,e piplus n), events
# loaded 189353 (e,e piminus ) events and  16 (e,e piminus n), events
# 17/101
# loaded 495086 (e,e piplus ) events and  50 (e,e piplus n), events
# loaded 204440 (e,e piminus ) events and  12 (e,e piminus n), events
# 18/101
# loaded 461398 (e,e piplus ) events and  44 (e,e piplus n), events
# loaded 189376 (e,e piminus ) events and  17 (e,e piminus n), events
# 19/101
# loaded 157587 (e,e piplus ) events and  20 (e,e piplus n), events
# loaded 64933 (e,e piminus ) events and  7 (e,e piminus n), events
# 20/101
# loaded 469341 (e,e piplus ) events and  39 (e,e piplus n), events
# loaded 192241 (e,e piminus ) events and  10 (e,e piminus n), events
# 21/101
# loaded 461772 (e,e piplus ) events and  43 (e,e piplus n), events
# loaded 188890 (e,e piminus ) events and  19 (e,e piminus n), events
# 22/101
# loaded 184828 (e,e piplus ) events and  12 (e,e piplus n), events
# loaded 75515 (e,e piminus ) events and  4 (e,e piminus n), events
# 23/101
# loaded 413743 (e,e piplus ) events and  39 (e,e piplus n), events
# loaded 169685 (e,e piminus ) events and  10 (e,e piminus n), events
# 24/101
# loaded 433498 (e,e piplus ) events and  63 (e,e piplus n), events
# loaded 178828 (e,e piminus ) events and  19 (e,e piminus n), events
# 25/101
# loaded 482814 (e,e piplus ) events and  63 (e,e piplus n), events
# loaded 198460 (e,e piminus ) events and  17 (e,e piminus n), events
# 26/101
# loaded 418674 (e,e piplus ) events and  38 (e,e piplus n), events
# loaded 172005 (e,e piminus ) events and  13 (e,e piminus n), events
# 27/101
# loaded 215789 (e,e piplus ) events and  17 (e,e piplus n), events
# loaded 88418 (e,e piminus ) events and  2 (e,e piminus n), events
# 28/101
# loaded 505315 (e,e piplus ) events and  47 (e,e piplus n), events
# loaded 206951 (e,e piminus ) events and  11 (e,e piminus n), events
# 29/101
# loaded 465932 (e,e piplus ) events and  50 (e,e piplus n), events
# loaded 191835 (e,e piminus ) events and  13 (e,e piminus n), events
# 30/101
# loaded 466908 (e,e piplus ) events and  47 (e,e piplus n), events
# loaded 190949 (e,e piminus ) events and  13 (e,e piminus n), events
# 31/101
# loaded 134621 (e,e piplus ) events and  18 (e,e piplus n), events
# loaded 55589 (e,e piminus ) events and  5 (e,e piminus n), events
# 32/101
# loaded 243732 (e,e piplus ) events and  33 (e,e piplus n), events
# loaded 99891 (e,e piminus ) events and  9 (e,e piminus n), events
# 33/101
# loaded 502765 (e,e piplus ) events and  52 (e,e piplus n), events
# loaded 206566 (e,e piminus ) events and  14 (e,e piminus n), events
# 34/101
# loaded 130328 (e,e piplus ) events and  7 (e,e piplus n), events
# loaded 53539 (e,e piminus ) events and  6 (e,e piminus n), events
# 35/101
# loaded 503716 (e,e piplus ) events and  62 (e,e piplus n), events
# loaded 206132 (e,e piminus ) events and  9 (e,e piminus n), events
# 36/101
# loaded 507847 (e,e piplus ) events and  46 (e,e piplus n), events
# loaded 207740 (e,e piminus ) events and  13 (e,e piminus n), events
# 37/101
# loaded 332917 (e,e piplus ) events and  29 (e,e piplus n), events
# loaded 136508 (e,e piminus ) events and  6 (e,e piminus n), events
# 38/101
# loaded 526445 (e,e piplus ) events and  58 (e,e piplus n), events
# loaded 216613 (e,e piminus ) events and  17 (e,e piminus n), events
# 39/101
# loaded 490910 (e,e piplus ) events and  52 (e,e piplus n), events
# loaded 200799 (e,e piminus ) events and  13 (e,e piminus n), events
# 40/101
# loaded 491014 (e,e piplus ) events and  48 (e,e piplus n), events
# loaded 200804 (e,e piminus ) events and  7 (e,e piminus n), events
# 41/101
# loaded 363331 (e,e piplus ) events and  31 (e,e piplus n), events
# loaded 149658 (e,e piminus ) events and  6 (e,e piminus n), events
# 42/101
# loaded 496619 (e,e piplus ) events and  52 (e,e piplus n), events
# loaded 202742 (e,e piminus ) events and  18 (e,e piminus n), events
# 43/101
# loaded 240724 (e,e piplus ) events and  16 (e,e piplus n), events
# loaded 98306 (e,e piminus ) events and  8 (e,e piminus n), events
# 44/101
# loaded 540350 (e,e piplus ) events and  66 (e,e piplus n), events
# loaded 221207 (e,e piminus ) events and  10 (e,e piminus n), events
# 45/101
# loaded 536267 (e,e piplus ) events and  45 (e,e piplus n), events
# loaded 220305 (e,e piminus ) events and  7 (e,e piminus n), events
# 46/101
# loaded 478640 (e,e piplus ) events and  50 (e,e piplus n), events
# loaded 196161 (e,e piminus ) events and  5 (e,e piminus n), events
# 47/101
# loaded 493158 (e,e piplus ) events and  51 (e,e piplus n), events
# loaded 203070 (e,e piminus ) events and  19 (e,e piminus n), events
# 48/101
# loaded 466235 (e,e piplus ) events and  44 (e,e piplus n), events
# loaded 190666 (e,e piminus ) events and  14 (e,e piminus n), events
# 49/101
# loaded 446318 (e,e piplus ) events and  40 (e,e piplus n), events
# loaded 182707 (e,e piminus ) events and  12 (e,e piminus n), events
# 50/101
# loaded 437096 (e,e piplus ) events and  52 (e,e piplus n), events
# loaded 180408 (e,e piminus ) events and  11 (e,e piminus n), events
# 51/101
# loaded 544726 (e,e piplus ) events and  38 (e,e piplus n), events
# loaded 222823 (e,e piminus ) events and  22 (e,e piminus n), events
# 52/101
# loaded 527628 (e,e piplus ) events and  67 (e,e piplus n), events
# loaded 215695 (e,e piminus ) events and  14 (e,e piminus n), events
# 53/101
# loaded 180043 (e,e piplus ) events and  23 (e,e piplus n), events
# loaded 74218 (e,e piminus ) events and  2 (e,e piminus n), events
# 54/101
# loaded 350950 (e,e piplus ) events and  38 (e,e piplus n), events
# loaded 144201 (e,e piminus ) events and  6 (e,e piminus n), events
# 55/101
# loaded 430098 (e,e piplus ) events and  69 (e,e piplus n), events
# loaded 176060 (e,e piminus ) events and  12 (e,e piminus n), events
# 56/101
# loaded 524126 (e,e piplus ) events and  56 (e,e piplus n), events
# loaded 215605 (e,e piminus ) events and  19 (e,e piminus n), events
# 57/101
# loaded 492216 (e,e piplus ) events and  44 (e,e piplus n), events
# loaded 201877 (e,e piminus ) events and  19 (e,e piminus n), events
# 58/101
# loaded 42090 (e,e piplus ) events and  1 (e,e piplus n), events
# loaded 17185 (e,e piminus ) events and  0 (e,e piminus n), events
# 59/101
# loaded 458769 (e,e piplus ) events and  48 (e,e piplus n), events
# loaded 188022 (e,e piminus ) events and  9 (e,e piminus n), events
# 60/101
# loaded 472952 (e,e piplus ) events and  40 (e,e piplus n), events
# loaded 194057 (e,e piminus ) events and  10 (e,e piminus n), events
# 61/101
# loaded 499893 (e,e piplus ) events and  77 (e,e piplus n), events
# loaded 204133 (e,e piminus ) events and  16 (e,e piminus n), events
# 62/101
# loaded 405456 (e,e piplus ) events and  51 (e,e piplus n), events
# loaded 161885 (e,e piminus ) events and  11 (e,e piminus n), events
# 63/101
# loaded 283994 (e,e piplus ) events and  32 (e,e piplus n), events
# loaded 117736 (e,e piminus ) events and  13 (e,e piminus n), events
# 64/101
# loaded 305035 (e,e piplus ) events and  30 (e,e piplus n), events
# loaded 125759 (e,e piminus ) events and  10 (e,e piminus n), events
# 65/101
# loaded 290639 (e,e piplus ) events and  33 (e,e piplus n), events
# loaded 118435 (e,e piminus ) events and  10 (e,e piminus n), events
# 66/101
# loaded 283124 (e,e piplus ) events and  28 (e,e piplus n), events
# loaded 115882 (e,e piminus ) events and  6 (e,e piminus n), events
# 67/101
# loaded 286739 (e,e piplus ) events and  30 (e,e piplus n), events
# loaded 117446 (e,e piminus ) events and  8 (e,e piminus n), events
# 68/101
# loaded 276834 (e,e piplus ) events and  31 (e,e piplus n), events
# loaded 113718 (e,e piminus ) events and  10 (e,e piminus n), events
# 69/101
# loaded 188883 (e,e piplus ) events and  19 (e,e piplus n), events
# loaded 77020 (e,e piminus ) events and  3 (e,e piminus n), events
# 70/101
# loaded 288459 (e,e piplus ) events and  30 (e,e piplus n), events
# loaded 118186 (e,e piminus ) events and  14 (e,e piminus n), events
# 71/101
# loaded 193070 (e,e piplus ) events and  15 (e,e piplus n), events
# loaded 78420 (e,e piminus ) events and  4 (e,e piminus n), events
# 72/101
# loaded 29432 (e,e piplus ) events and  1 (e,e piplus n), events
# loaded 12166 (e,e piminus ) events and  0 (e,e piminus n), events
# 73/101
# loaded 116721 (e,e piplus ) events and  15 (e,e piplus n), events
# loaded 47566 (e,e piminus ) events and  0 (e,e piminus n), events
# 74/101
# loaded 285537 (e,e piplus ) events and  23 (e,e piplus n), events
# loaded 116273 (e,e piminus ) events and  9 (e,e piminus n), events
# 75/101
# loaded 288116 (e,e piplus ) events and  25 (e,e piplus n), events
# loaded 117825 (e,e piminus ) events and  5 (e,e piminus n), events
# 76/101
# loaded 283580 (e,e piplus ) events and  30 (e,e piplus n), events
# loaded 116187 (e,e piminus ) events and  15 (e,e piminus n), events
# 77/101
# loaded 9879 (e,e piplus ) events and  1 (e,e piplus n), events
# loaded 4023 (e,e piminus ) events and  0 (e,e piminus n), events
# 78/101
# loaded 286577 (e,e piplus ) events and  42 (e,e piplus n), events
# loaded 118626 (e,e piminus ) events and  6 (e,e piminus n), events
# 79/101
# loaded 290710 (e,e piplus ) events and  39 (e,e piplus n), events
# loaded 118490 (e,e piminus ) events and  7 (e,e piminus n), events
# 80/101
# loaded 296869 (e,e piplus ) events and  35 (e,e piplus n), events
# loaded 121240 (e,e piminus ) events and  10 (e,e piminus n), events
# 81/101
# loaded 288085 (e,e piplus ) events and  21 (e,e piplus n), events
# loaded 118603 (e,e piminus ) events and  13 (e,e piminus n), events
# 82/101
# loaded 286227 (e,e piplus ) events and  27 (e,e piplus n), events
# loaded 117272 (e,e piminus ) events and  8 (e,e piminus n), events
# 83/101
# loaded 276615 (e,e piplus ) events and  42 (e,e piplus n), events
# loaded 113388 (e,e piminus ) events and  10 (e,e piminus n), events
# 84/101
# loaded 288616 (e,e piplus ) events and  27 (e,e piplus n), events
# loaded 118320 (e,e piminus ) events and  13 (e,e piminus n), events
# 85/101
# loaded 190762 (e,e piplus ) events and  28 (e,e piplus n), events
# loaded 78302 (e,e piminus ) events and  5 (e,e piminus n), events
# 86/101
# loaded 35298 (e,e piplus ) events and  1 (e,e piplus n), events
# loaded 14620 (e,e piminus ) events and  1 (e,e piminus n), events
# 87/101
# loaded 115256 (e,e piplus ) events and  16 (e,e piplus n), events
# loaded 47151 (e,e piminus ) events and  3 (e,e piminus n), events
# 88/101
# loaded 287571 (e,e piplus ) events and  21 (e,e piplus n), events
# loaded 117906 (e,e piminus ) events and  3 (e,e piminus n), events
# 89/101
# loaded 282084 (e,e piplus ) events and  14 (e,e piplus n), events
# loaded 115412 (e,e piminus ) events and  7 (e,e piminus n), events
# 90/101
# loaded 192721 (e,e piplus ) events and  17 (e,e piplus n), events
# loaded 78669 (e,e piminus ) events and  1 (e,e piminus n), events
# 91/101
# loaded 47761 (e,e piplus ) events and  5 (e,e piplus n), events
# loaded 19746 (e,e piminus ) events and  1 (e,e piminus n), events
# 92/101
# loaded 296953 (e,e piplus ) events and  47 (e,e piplus n), events
# loaded 121409 (e,e piminus ) events and  10 (e,e piminus n), events
# 93/101
# loaded 291966 (e,e piplus ) events and  36 (e,e piplus n), events
# loaded 119201 (e,e piminus ) events and  5 (e,e piminus n), events
# 94/101
# loaded 106629 (e,e piplus ) events and  13 (e,e piplus n), events
# loaded 43671 (e,e piminus ) events and  2 (e,e piminus n), events
# 95/101
# loaded 283935 (e,e piplus ) events and  24 (e,e piplus n), events
# loaded 115792 (e,e piminus ) events and  1 (e,e piminus n), events
# 96/101
# loaded 301974 (e,e piplus ) events and  26 (e,e piplus n), events
# loaded 123869 (e,e piminus ) events and  9 (e,e piminus n), events
# 97/101
# loaded 73860 (e,e piplus ) events and  9 (e,e piplus n), events
# loaded 30991 (e,e piminus ) events and  0 (e,e piminus n), events
# 98/101
# loaded 87833 (e,e piplus ) events and  14 (e,e piplus n), events
# loaded 35568 (e,e piminus ) events and  0 (e,e piminus n), events
# 99/101
# loaded 14953 (e,e piplus ) events and  1 (e,e piplus n), events
# loaded 6202 (e,e piminus ) events and  0 (e,e piminus n), events
# 100/101

# %% [markdown]
# ## Super ratio as a function of Bjorken $x$, or for a moving proton $x'$
# defined as
# $ x' = Q^2/((W')^2 - m_N^2 + Q^2)$

# %%
x_bins   = np.linspace(0.2,0.6,10) #np.concatenate([np.linspace(0.2,0.45,6), np.linspace(0.5,0.75,8) ])
x_bins
# Out:
# array([0.2       , 0.24444444, 0.28888889, 0.33333333, 0.37777778,
#        0.42222222, 0.46666667, 0.51111111, 0.55555556, 0.6       ])

# %%
var_e_e_pi      = 'xB'
xlabel_e_e_pi   = "Bjorken $x$"

var_e_e_pi_n    = 'xB'
# var_e_e_pi_n    = 'xPrime2'

if var_e_e_pi_n == 'xB':
    
    xlabel_e_e_pi_n = "Bjorken $x$"
    SuperRatio_label= "$(x/x)$"

elif var_e_e_pi_n == 'xPrime2':
        
    # xlabel_e_e_pi_n = "$x' = Q^2/2\cdot((m_d - E_s)\omega + p_n \cdot q)$"
    xlabel_e_e_pi_n = "$x' = Q^2/(W'^2 - m_N^2 + Q^2)$"
    SuperRatio_label= "$(x'/x)$"

# %%
R_e_e_pi_pips_to_pims, R_e_e_pi_pips_to_pims_errup, R_e_e_pi_pips_to_pims_errdw     = compute_ratio_pips_to_pims(df_dict=e_e_pi  , var=var_e_e_pi, bins=x_bins)
R_e_e_pi_n_pips_to_pims, R_e_e_pi_n_pips_to_pims_errup, R_e_e_pi_n_pips_to_pims_errdw = compute_ratio_pips_to_pims(df_dict=e_e_pi_n, var=var_e_e_pi_n, bins=x_bins)

SuperR     = R_e_e_pi_n_pips_to_pims / R_e_e_pi_pips_to_pims
SuperR_errup = SuperR * np.sqrt( np.square(R_e_e_pi_n_pips_to_pims_errup/R_e_e_pi_n_pips_to_pims)+                                                                                          
                                np.square(R_e_e_pi_pips_to_pims_errup  /R_e_e_pi_pips_to_pims) ) 
SuperR_errdw = SuperR * np.sqrt( np.square(R_e_e_pi_n_pips_to_pims_errdw/R_e_e_pi_n_pips_to_pims)+                                                                                          
                                np.square(R_e_e_pi_pips_to_pims_errdw  /R_e_e_pi_pips_to_pims) )
# Out:
# /var/folders/42/n5_htl9n34j9wpgd5rqsnmv40000gn/T/ipykernel_44546/2687261668.py:4: RuntimeWarning: invalid value encountered in true_divide
#   SuperR     = R_e_e_pi_n_pips_to_pims / R_e_e_pi_pips_to_pims
# /var/folders/42/n5_htl9n34j9wpgd5rqsnmv40000gn/T/ipykernel_44546/2687261668.py:5: RuntimeWarning: invalid value encountered in true_divide
#   SuperR_errup = SuperR * np.sqrt( np.square(R_e_e_pi_n_pips_to_pims_errup/R_e_e_pi_n_pips_to_pims)+
# /var/folders/42/n5_htl9n34j9wpgd5rqsnmv40000gn/T/ipykernel_44546/2687261668.py:6: RuntimeWarning: invalid value encountered in true_divide
#   np.square(R_e_e_pi_pips_to_pims_errup  /R_e_e_pi_pips_to_pims) )
# /var/folders/42/n5_htl9n34j9wpgd5rqsnmv40000gn/T/ipykernel_44546/2687261668.py:7: RuntimeWarning: invalid value encountered in true_divide
#   SuperR_errdw = SuperR * np.sqrt( np.square(R_e_e_pi_n_pips_to_pims_errdw/R_e_e_pi_n_pips_to_pims)+
# /var/folders/42/n5_htl9n34j9wpgd5rqsnmv40000gn/T/ipykernel_44546/2687261668.py:8: RuntimeWarning: invalid value encountered in true_divide
#   np.square(R_e_e_pi_pips_to_pims_errdw  /R_e_e_pi_pips_to_pims) )

# %%
h = dict()

fig = plt.figure(figsize=(14,9))
ax  = fig.add_subplot(2,2,1)
for pi_charge_name,pi_color,pi_label in zip(pi_charge_names,pi_colors,pi_labels):
    x,h[pi_charge_name],x_err= plot_step_hist(df=e_e_pi[pi_charge_name], var=var_e_e_pi, bins=x_bins , label="$(e,e'"+pi_label+")$" )
set_axes(ax,xlabel_e_e_pi,'Counts',title="All $(e,e'\pi)$",do_add_grid=True, do_add_legend=True, fontsize=fontsize)


ax  = fig.add_subplot(2,2,2)
for pi_charge_name,pi_color,pi_label in zip(pi_charge_names,pi_colors,pi_labels):
    x,h[pi_charge_name + 'n'],x_err = plot_step_hist(df=e_e_pi_n[pi_charge_name], var=var_e_e_pi_n, bins=x_bins , label="$(e,e'"+pi_label+"n)$" )
set_axes(ax,xlabel_e_e_pi_n,'',title='Tagged $n$ above 275 MeV/c',do_add_grid=True, do_add_legend=True, fontsize=fontsize)

ax  = fig.add_subplot(2,2,3)
ax.errorbar( x=x, xerr=x_err, y=R_e_e_pi_pips_to_pims, 
            yerr=[R_e_e_pi_pips_to_pims_errdw,R_e_e_pi_pips_to_pims_errup] ,
            marker='o', linestyle='None',
            capsize=2,
            color='forestgreen',label="$(e,e'\pi^+)/(e,e'\pi^-)$")
ax.errorbar( x=x, xerr=x_err, y=R_e_e_pi_n_pips_to_pims, 
            yerr=[R_e_e_pi_n_pips_to_pims_errdw,R_e_e_pi_n_pips_to_pims_errup] , 
            marker='o', linestyle='None',
            capsize=2 ,
            color='black',label="$(e,e'\pi^+n)/(e,e'\pi^-n)$")

set_axes(ax,'$x$',"$N_{(e,e'\pi^+)}/N_{(e,e'\pi^-)}$",
                     title='$\pi^+/\pi^-$ ratio',
         do_add_grid=True, do_add_legend=True, fontsize=fontsize)


ax  = fig.add_subplot(2,2,4)
ax.errorbar( x=x, xerr=x_err, y=SuperR, 
            yerr=[SuperR_errdw,SuperR_errup],
            marker='o', linestyle='None',             
            capsize=2,
            color='black')

set_axes(ax,"$x$",
         "$\\frac{N_{(e,e'\pi^+n)}/N_{(e,e'\pi^-n)}}{N_{(e,e'\pi^+)}/N_{(e,e'\pi^-)}}$",
         title="Super ratio of " + SuperRatio_label,
         do_add_grid=True, fontsize=fontsize)

plt.tight_layout()
# Out:
# /usr/local/lib/python3.9/site-packages/matplotlib/axes/_base.py:2283: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)

# %% [markdown]
# # Isolate $(e,e'\pi^+)/(e,e'\pi^-)$ ratio as a function of $z$
# Our naive expectation is that this cross section ratio equals 4

# %% [markdown]
# ### Poor-man's acceptance correction: Can we apply tight fiducial cuts on $\pi^+$ and $\pi^-$?

# %%
theta_min,theta_max = 15,20

# %%
Nmax = 1000000
bins = (np.linspace(0,40,100),np.linspace(-180,180,100))
pips = e_e_pi['piplus'][0:Nmax]
pims = e_e_pi['piminus'][0:Nmax]

fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(1,2,1)
plt.hist2d( pips['pi_Theta']*r2d, pips['pi_Phi']*r2d ,bins=bins, cmap='hot_r');
plt.plot([theta_min,theta_min],[-180,180],'--b',[theta_max,theta_max],[-180,180],'--b')
set_axes(ax,'$\\theta$ [deg.]','$\phi$ [deg.]',title='$\pi^+$', do_add_grid=True)


ax = fig.add_subplot(1,2,2)
plt.hist2d( pims['pi_Theta']*r2d, pims['pi_Phi']*r2d ,bins=bins, cmap='hot_r');
plt.plot([theta_min,theta_min],[-180,180],'--b',[theta_max,theta_max],[-180,180],'--b')
set_axes(ax,'$\\theta$ [deg.]','$\phi$ [deg.]',title='$\pi^-$', do_add_grid=True)
# e_e_pi['piplus'][0:1]#['theta'][0:10]

plt.tight_layout()

# %% [markdown]
# ### Produce the plot

# %%
z_bins = [0.3,0.4,0.5,0.6,0.7,0.8,0.9]
z_width = 0.01
var_e_e_pi = 'xB'
xlabel_e_e_pi   = "Bjorken $x$"

# %%
Rpips2pims, Rpips2pims_errup, Rpips2pims_errdw = dict(), dict(), dict()
for z_bin in z_bins:
    z_min,z_max = z_bin-z_width,z_bin+z_width
    Rpips2pims[z_bin], Rpips2pims_errup[z_bin], Rpips2pims_errdw[z_bin] = compute_ratio_pips_to_pims(df_dict=e_e_pi  , 
                                                                                                     var=var_e_e_pi, bins=x_bins, 
                                                                                                     z_min=z_min,z_max=z_max, 
                                                                                                     theta_min=theta_min,
                                                                                                     theta_max=theta_max)

    print(z_bin,Rpips2pims[z_bin],Rpips2pims_errup[z_bin],Rpips2pims_errdw[z_bin])
print('done')
# Out:
# 0.3 [1.72432071 1.81304449 1.81387864 1.81852664 1.82259008 1.86857708
#  1.84699454 1.84663073 1.87011349] [0.01144769 0.01299775 0.01479995 0.01742909 0.02073885 0.02573081
#  0.03094852 0.03764165 0.0474992 ] [0.01144769 0.01299775 0.01479995 0.01742909 0.02073885 0.02573081
#  0.03094852 0.03764165 0.0474992 ]
# 0.4 [1.63014329 1.70606207 1.77364524 1.80396699 1.81486343 1.83000238
#  1.79169191 1.7323924  1.79467203] [0.00947035 0.00986295 0.0110005  0.01267    0.0147081  0.01755131
#  0.02080561 0.02571932 0.03550349] [0.00947035 0.00986295 0.0110005  0.01267    0.0147081  0.01755131
#  0.02080561 0.02571932 0.03550349]
# 0.5 [1.71443402 1.75472781 1.78880959 1.82414536 1.81538287 1.78952389
#  1.74227175 1.80388979 1.81485547] [0.01290724 0.01277645 0.01354674 0.01505508 0.01700775 0.0199194
#  0.02392622 0.0320109  0.04323438] [0.01290724 0.01277645 0.01354674 0.01505508 0.01700775 0.0199194
#  0.02392622 0.0320109  0.04323438]
# 0.6 [1.84909658 1.86598862 1.89170688 1.84981266 1.87255876 1.89351141
#  1.83725071 1.85583185 1.97794118] [0.01760856 0.01678763 0.01751967 0.01829671 0.02109827 0.02544695
#  0.03046629 0.03961009 0.05771964] [0.01760856 0.01678763 0.01751967 0.01829671 0.02109827 0.02544695
#  0.03046629 0.03961009 0.05771964]
# 0.7 [1.99128849 1.93860619 1.88463906 1.92570122 1.91874443 1.95027537
#  1.94376528 2.01441516 2.15015244] [0.02456369 0.02121618 0.02045448 0.02225727 0.02496731 0.03008995
#  0.03740347 0.0500094  0.07185111] [0.02456369 0.02121618 0.02045448 0.02225727 0.02496731 0.03008995
#  0.03740347 0.0500094  0.07185111]
# 0.8 [2.12456366 2.03555659 2.05491872 2.05494628 2.06893641 2.10749386
#  2.22468887 2.24914481 2.35201794] [0.03492291 0.02679539 0.02557714 0.02650516 0.02988779 0.03661849
#  0.04912257 0.06454735 0.09401368] [0.03492291 0.02679539 0.02557714 0.02650516 0.02988779 0.03661849
#  0.04912257 0.06454735 0.09401368]
# 0.9 [2.15265662 1.99664054 2.02633642 2.1798008  2.26805054 2.47989539
#  2.63459516 2.67293907 2.55591054] [0.05187441 0.03341688 0.03100545 0.03480138 0.04089506 0.05311413
#  0.07095446 0.09379276 0.12049279] [0.05187441 0.03341688 0.03100545 0.03480138 0.04089506 0.05311413
#  0.07095446 0.09379276 0.12049279]
# done

# %%
fig = plt.figure(figsize=(9,6))
ax  = fig.add_subplot(1,1,1)
for z_bin in z_bins:
    ax.errorbar(x=x, xerr=x_err, 
                y=Rpips2pims[z_bin], yerr=(Rpips2pims_errup[z_bin],Rpips2pims_errdw[z_bin]),
                marker='o',markeredgecolor='k',
                label='$z=%.2f\pm%.2f$'%(z_bin,z_width))
    
set_axes(ax,xlabel_e_e_pi,"$N(e,e'\pi^+)/N(e,e'\pi^-)$",title="$\pi^+/\pi^-$ ratio as a function of $x$",
         do_add_grid=True, do_add_legend=False, fontsize=fontsize,ylim=(1,3));
# ax.legend(bbox_to_anchor=(1.,1.5),loc='right',fontsize=fontsize)

# %% [markdown]
# ## Plot the ratio to the expected SIDIS ratio
# $$\sigma^{\pi^+}_d/\sigma^{\pi^-}_d
# \sim
# \frac{4.58 + 0.16z^2 - 0.51 z}
# {3.32 + 0.64 z^2 - 2.04z}
# $$

# %%
fig = plt.figure(figsize=(12,8))
for z_bin,subplot_idx in zip(z_bins[0:6],range(1,7)):
    ax = fig.add_subplot(2,3,subplot_idx)
    
    z = z_bin
    R_SIDIS = (4.58 + 0.16*z*z - 0.51*z)/(3.32 + 0.64*z*z - 2.04*z)
    ax.errorbar(x=x, xerr=x_err, 
                y = Rpips2pims[z_bin]/R_SIDIS, 
                yerr= (Rpips2pims_errup[z_bin]/R_SIDIS, Rpips2pims_errdw[z_bin]/R_SIDIS),
                marker='o',markeredgecolor='k',
                label='$z=%.2f\pm%.2f$'%(z_bin,z_width))
    ax.plot([0.2,0.6],[1,1],'--k')
    set_axes(ax,
             x_label=xlabel_e_e_pi if subplot_idx>3 else '',
             y_label="$\\frac{N(e,e'\pi^+)/N(e,e'\pi^-)}{prediction}$" if subplot_idx%3==1 else '',
             remove_ticks_x=False if subplot_idx>3 else True,
             remove_ticks_y=False if subplot_idx%3==1 else True,
             title="$z=%.2f\pm%.2f$"%(z_bin,z_width),
             do_add_grid=True, do_add_legend=False, fontsize=fontsize,
             ylim=(0.8,1.2),yticks=(0.8,0.9,1,1.1,1.2));

plt.tight_layout()

# %%
tight_layout
