# %% [markdown]
# # Free-p cross-section ratio of $p(e,e'\pi^+)/p(e,e'\pi^+)$
#
# $$\left(\frac{\sigma(e,e'\pi^+)}{\sigma(e,e'\pi^+)}\right)$$
#
# last edit Jan-24, 2023

# %% [markdown]
# ## Imports and definitions

# %%
import sys; 
software_path = '/Users/erezcohen/Desktop/Software/'
sys.path.insert(0, software_path + '/mySoftware/Python/');
sys.path.insert(0, software_path + '/CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/AcceptanceCorrections/');
sys.path.insert(0, software_path + '/CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/');
from my_tools                     import *; 
from plot_tools                   import *;
from my_data_analysis_tools       import *;
from acceptance_correction_tools  import *;
from sidis_analysis_tools         import *;

# %%
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['mathtext.fontset']    = 'stix'
plt.rcParams['font.family']         = 'STIXGeneral'

# %% [markdown]
# ## (1) Load data

# %%
_,_,e_e_pi_FreeP = load_SIDIS_data( Nruns = -1,
                                   FreePsubdirname = "nSidis_12Jan2023_commit_ad849e5", 
                                   do_e_e_pi=False, 
                                   do_e_e_pi_n=False , fdebug=0)
# Out:
# Done loading files.

# %% [markdown]
# ## (2) Apply selection cuts not previously imposed

# %%
import time

# %%
print('number of pi+ events: %.1f'%(len(e_e_pi_FreeP['piplus'])/1e6),'M')
# Out:
# number of pi+ events: 26.0 M

# %%
Nevents = -1
t0= time.time()
_,_,e_e_pi_FreeP_pass_cuts,_ = apply_further_selection_cuts_to_data(fdebug=1, 
                                                            NeventsMax=Nevents,
                                                            NMaxPerSubset=500000);
t1 = time.time() 
print("Time elapsed: %.2f"%(t1 - t0), 'sec (%g us/event)'%((t1 - t0)/Nevents*1.e6)) # CPU seconds elapsed (floating point)
# Out:
# Applying selection cuts not previously imposed
# (3) Applying cuts to p(e,e'π) data
# Apply a π+/π- acceptance matching cut on the in p-theta plane
# Applying p-theta on cut for piplus which includes 26020200 events
# Applying p-theta on cut for piplus on 26020200 events
# 4442660 in sector 1
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:626: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_after_cut = df_after_cut.append(df_in_sector_pass_cut);
# 4312220 in sector 2
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:626: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_after_cut = df_after_cut.append(df_in_sector_pass_cut);
# 4302662 in sector 3
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:626: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_after_cut = df_after_cut.append(df_in_sector_pass_cut);
# 4268441 in sector 4
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:626: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_after_cut = df_after_cut.append(df_in_sector_pass_cut);
# 4347003 in sector 5
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:626: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_after_cut = df_after_cut.append(df_in_sector_pass_cut);
# 4347214 in sector 6
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:626: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_after_cut = df_after_cut.append(df_in_sector_pass_cut);
# Applying p-theta on cut for piminus which includes 8205571 events
# Applying p-theta on cut for piminus on 8205571 events
# 1393254 in sector 1
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:626: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_after_cut = df_after_cut.append(df_in_sector_pass_cut);
# 1368059 in sector 2
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:626: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_after_cut = df_after_cut.append(df_in_sector_pass_cut);
# 1344454 in sector 3
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:626: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_after_cut = df_after_cut.append(df_in_sector_pass_cut);
# 1356422 in sector 4
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:626: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_after_cut = df_after_cut.append(df_in_sector_pass_cut);
# 1346589 in sector 5
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:626: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_after_cut = df_after_cut.append(df_in_sector_pass_cut);
# 1396793 in sector 6
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:626: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_after_cut = df_after_cut.append(df_in_sector_pass_cut);
# Apply a cut on the missing mass of a (e,e'π) reaction: 1.3<Mx<5.0 GeV/c2
# p(e,e π+ )
# 26020200 events after original cut (100.0 %)
# 18435963 events after p-theta cut (70.9 %)
# 17583137 events after Mx cut (67.6 %)
# 17547449 events after Kinematical cut (67.4 %)
# p(e,e π- )
# 8205571 events after original cut (100.0 %)
# 7962701 events after p-theta cut (97.0 %)
# 7914114 events after Mx cut (96.4 %)
# 7897960 events after Kinematical cut (96.3 %)
#
# Done applying event-selection cuts
# Time elapsed: 88.85 sec (-8.88541e+07 us/event)

# %% [markdown]
# ## (3) Extract cross-section ratio as a function of Bjorken $x$
# For a standing proton use $x_B$, defined as
# $ x_B = Q^2/2m_p\omega$

# %%
z_bins   = np.arange(0.3,0.85,0.05)
z_widths = 0.01*np.ones(len(z_bins))
x_bins   = np.linspace(0.2,0.6,11)
x        = (x_bins[1:] + x_bins[:-1])/2
x_err    = (x_bins[1:] - x_bins[:-1])/2
print('x bins:',x_bins)
print('z bins:',z_bins)
for z_bin,z_width in zip(z_bins,z_widths):
    z_min,z_max = z_bin-z_width, z_bin+z_width
    print('%.3f < z < %.3f:'%(z_min,z_max))
# Out:
# x bins: [0.2  0.24 0.28 0.32 0.36 0.4  0.44 0.48 0.52 0.56 0.6 ]
# z bins: [0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65 0.7  0.75 0.8 ]
# 0.290 < z < 0.310:
# 0.340 < z < 0.360:
# 0.390 < z < 0.410:
# 0.440 < z < 0.460:
# 0.490 < z < 0.510:
# 0.540 < z < 0.560:
# 0.590 < z < 0.610:
# 0.640 < z < 0.660:
# 0.690 < z < 0.710:
# 0.740 < z < 0.760:
# 0.790 < z < 0.810:

# %%
var_label = "standing proton x"
# var_label = "moving proton x"

if   var_label == "standing proton x":
    var    = 'xB'
    xlabel = "Bjorken $x$"
    
elif var_label == "moving proton x":
    var    = 'xPrime2'
    xlabel = "$x' = Q^2/(W'^2 - m_N^2 + Q^2)$"

# %% [markdown]
# # (4) Extract tabular data and save results to file

# %%
extract_SIDIS_ratio(df_dict  = e_e_pi_FreeP_pass_cuts,
                           x_var    = var ,                           
                           x_bins   = x_bins,                           
                           z_bins   = z_bins,                           
                           z_widths = z_widths,                           
                           fdebug   = 0,
                           prefix   = 'FreeProton_SIDIS_ratio_',                           
                           suffix   = '')

# %%
prefix = 'FreeProton_SIDIS_ratio_'
suffix = ''
SIDIS_results = load_SIDIS_ratio(prefix = prefix, suffix = suffix, doPlotResults=True)
ax = plt.gca()
ax.set_ylim(1,2.5);

# %% [markdown]
# # (5) Extract modified results

# %% [markdown]
# ## (5.1) Results in different bins of $Q^2$

# %%
Q2_min_arr = [2.0,3.0,4.0,5.0]
Q2_max_arr = [3.0,4.0,5.0,7.0]

# %%
data_path= '/Users/erezcohen/Desktop/data/BAND/Results/Q2_bins/'
for Q2_min,Q2_max in zip(Q2_min_arr,Q2_max_arr):
    print(Q2_min,Q2_max)
    extract_SIDIS_ratio(df_dict  = e_e_pi_FreeP_pass_cuts,
                        x_var    = var ,
                        x_bins   = x_bins,
                        z_bins   = z_bins,
                        z_widths = z_widths,          
                        fdebug   = 0,
                        data_path= data_path,
                        prefix   = 'FreeProton_SIDIS_ratio_',                    
                        suffix   = '_%.1f_Q2_%.1f'%(Q2_min,Q2_max),
                        Q2_min   = Q2_min,
                        Q2_max   = Q2_max)
    
print('done.')
# Out:
# 2.0 3.0
# 3.0 4.0
# 4.0 5.0
# 5.0 7.0
# done.

# %% [markdown]
# ## (5.2) Results in different bins of $M_x$

# %%
M_x_min_arr = [0.0,1.3]
M_x_max_arr = [1.3,3.0]

# %%
for M_x_min,M_x_max in zip(M_x_min_arr,M_x_max_arr):
    print(M_x_min,M_x_max)
    extract_SIDIS_ratio(df_dict  = e_e_pi_FreeP_pass_cuts,
                        x_var    = var ,
                        x_bins   = x_bins,
                        z_bins   = z_bins,
                        z_widths = z_widths,          
                        fdebug   = 0,
                        data_path= '/Users/erezcohen/Desktop/data/BAND/Results/Mx_bins/',
                        prefix   = 'FreeProton_SIDIS_ratio_',                    
                        suffix   = '_Mx_%.2f-%.2f_GeV'%(M_x_min,M_x_max),
                        M_x_min  = M_x_min,
                        M_x_max  = M_x_max)
    
print('done.')
# Out:
# 0.0 1.3
# /opt/homebrew/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/homebrew/lib/python3.10/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in divide
#   ret = arr.dtype.type(ret / rcount)
# 1.3 3.0
# done.

# %% [markdown]
# ## (5.2) extract results for many more bins in $z$

# %%
# z_bins   = np.arange(0.3,0.8,0.01)
# z_widths = 0.001*np.ones(len(z_bins))

# prefix = 'FreeProton_SIDIS_ratio_'
# suffix = ''

# %%
# extract_SIDIS_ratio(df_dict  = e_e_pi_pass_cuts,                                
#                            x_var    = var ,                           
#                            x_bins   = x_bins,                           
#                            z_bins   = z_bins,                           
#                            z_widths = z_widths,                           
#                            fdebug   = 0,
#                            prefix   = 'FreeProton_SIDIS_ratio_',                           
#                            suffix   = '')

# %%
# SIDIS_results = load_SIDIS_ratio_DataFrame(z_bins=z_bins,z_widths=z_widths,
#                                            prefix = prefix, suffix = suffix, 
#                                            doPlotResults=True)

# %% [markdown]
# # arxiv
