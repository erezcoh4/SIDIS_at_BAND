# %% [markdown]
# # "White" MC - cross-section ratio of $(e,e'\pi^+)/(e,e'\pi^+)$
#
# last edit Feb-13, 2023

# %% [markdown]
# ## Imports and definitions

# %%
import sys; 
software_path = '/Users/erezcohen/Desktop/Software/'
sys.path.insert(0, software_path + '/mySoftware/Python/');
sys.path.insert(0, software_path + '/CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/AcceptanceCorrections/');
sys.path.insert(0, software_path + '/CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/');
from my_tools                     import *; 
from plot_tools                   import *;
from my_data_analysis_tools       import *;
from acceptance_correction_tools  import *;
from sidis_analysis_tools         import *;

# %%
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['mathtext.fontset']    = 'stix'
plt.rcParams['font.family']         = 'STIXGeneral'

# %% [markdown]
# ## (1) Load data

# %%
# ----------------------- #
def load_SIDIS_data(rgb_runs_filenames = ["good_runs_10-2-final.txt"],
                    main_data_path  = '/Users/erezcohen/Desktop/data/BAND/',
                    Nruns           = 1,
                    do_e_e_pi       = True,
                    do_e_e_pi_n     = True,
                    do_e_e_pi_FreeP = True,
                    do_e_e_pi_GEMC  = False, # "white" spectrum of (e,e'π) events with no physics
                    do_all_vars     = False,
                    fdebug          = 2,
                    prefix          = "sidisdvcs",
                    subdirname      = "",
                    taggedsubdirname= "",
                    FreePsubdirname = "",
                    FreeP_prefix    = "nSidis",
                    GEMCsubdirname = "gcard_rgb_spring2019/1M_events",
                    rga_runs_filename = "rga_data/rga_nsidis_runs_10-6.txt"):#{
    '''
    e_e_pi, e_e_pi_n, e_e_pi_FreeP = load_SIDIS_data()
    e_e_pi, e_e_pi_n, e_e_pi_FreeP, e_e_pi_GEMC = load_SIDIS_data(do_e_e_pi_GEMC=True)

    Load SIDIS data, and fill e_e_pi and e_e_pi_n with data
    last update Feb-13, 2023
    
    input:
    -------------
    do_e_e_pi       flag to read d(e,e'π) data  from RGB - takes much time for a large number of runs
    do_e_e_pi_n     flag to read d(e,e'πn) data from RGB - takes less time
    do_e_e_pi_FreeP flag to read p(e,e'π) data from RGA  - takes much time
    prefix          "sidisdvcs" / "inc"      - inclusive skimming train
    subdirname      "With_W0.5cut" / "With_W2.5cut"
    do_e_e_pi_GEMC  flag to add e_e_pi_GEMC
    
    Comments:
    -------------
    e_e_pi, e_e_pi_n, e_e_pi_FreeP       dict(['piplus','piminus'])
    e.g. :
    e_e_pi['piplus'] = pandas.DataFrame( (e,e'π) events data )
    
    
    '''
    global e_e_pi, e_e_pi_n, e_e_pi_FreeP;

    if taggedsubdirname=="": taggedsubdirname = subdirname;
    
    e_e_pi_data_path       = main_data_path + 'SIDIS_skimming/' + prefix + '/' + subdirname + '/'
    e_e_pi_n_data_path     = main_data_path + 'merged_SIDIS_and_BAND_skimming/' + prefix + '/' + taggedsubdirname + '/'
    e_e_pi_FreeP_data_path = main_data_path + 'RGA_Free_proton/' + FreeP_prefix + '/'+ FreePsubdirname + '/'
    e_e_pi_GEMC_data_path  = main_data_path + 'AcceptanceCorrection/GEMCimulationOuputFiles/' + GEMCsubdirname + '/'

    if len(rgb_runs_filenames)==1:#{
        rgb_runs = read_run_nunmbers( runs_filename=rgb_runs_filenames[0], Nruns=Nruns )
    #}
    else:#{
        rgb_runs = []
        for f in rgb_runs_filenames:
            for run in read_run_nunmbers( runs_filename=f, Nruns=Nruns ):
                rgb_runs.append(run)
    #}
    rga_runs = read_run_nunmbers( runs_filename=rga_runs_filename, Nruns=Nruns)
    e_e_pi, e_e_pi_n, e_e_pi_FreeP = dict(),dict(),dict()
    if do_e_e_pi:#{
        for runnum,runIdx in zip(rgb_runs,range(len(rgb_runs))):#{
            if fdebug>1: print('Run number ',runnum,'(%d/%d runs)'%(runIdx+1,len(runs)))
            for pi_charge_name,pi_print in zip(pi_charge_names,pi_prints):
                if do_e_e_pi:#{
                    if do_all_vars:
                        eepi   = pd.read_csv(e_e_pi_data_path
                                         +'skimmed_SIDIS_'
                                         +prefix + '_'
                                         +'%06d_e_%s_selected_eepi_kinematics.csv'%(runnum,pi_charge_name))

                    else: # more economic
                        eepi   = pd.read_csv(e_e_pi_data_path
                                         +'skimmed_SIDIS_'
                                         +prefix + '_'
                                         +'%06d_e_%s_selected_eepi_kinematics.csv'%(runnum,pi_charge_name),
                                         usecols=['runnum','evnum',
                                                  'e_P','e_Theta','e_Phi',
                                                  'pi_P', 'pi_Theta', 'pi_Phi',
                                                  'Q2', 'W',
                                                  'xB', 'Zpi',
                                                  'M_x', 'e_DC_sector',
                                                  'pi_DC_sector','pi_qFrame_pT',
                                                  'pi_qFrame_pL','pi_qFrame_Phi'],
                                         dtype={'runnum':int,'evnum': int,
                                                'e_DC_sector':int, 'pi_DC_sector':int,
                                                'e_P':np.half,'e_Theta':np.half,'e_Phi':np.half,
                                                'pi_P':np.half,'pi_Theta':np.half, 'pi_Phi':np.half,
                                                'Q2':np.half,  'W':np.half,
                                                'xB':np.half, 'Zpi':np.half,
                                                'M_x':np.half,
                                                'pi_qFrame_pT':np.half,'pi_qFrame_pL':np.half,'pi_qFrame_Phi':np.half})

                    if runIdx==0: e_e_pi[pi_charge_name] = eepi
                    else:         e_e_pi[pi_charge_name] = pd.concat([e_e_pi[pi_charge_name],eepi])


                    if fdebug>1: print('Loaded',len(eepi)," d(e,e'"+pi_print+") events")

                #}
                if do_e_e_pi_n:#{
                    eepin = pd.read_csv(e_e_pi_n_data_path
                                        + 'skimmed_SIDIS_and_BAND_'
                                        + prefix + '_'
                                        + '%06d_e_%s_n.csv'%(runnum,pi_charge_name))

                    if fdebug>1: print('Loaded',len(eepin)," d(e,e'"+pi_print+"n) events")

                    if runIdx==0: e_e_pi_n[pi_charge_name] = eepin
                    else:         e_e_pi_n[pi_charge_name] = pd.concat([e_e_pi_n[pi_charge_name],eepin])
                #}
            #}
        #}
    #}
    if do_e_e_pi_FreeP:#{
        for runnum,runIdx in zip(rga_runs,range(len(rga_runs))):#{
            if fdebug>1: print('Free-P RGA Run number ',runnum,'(%d/%d runs)'%(runIdx+1,len(runs)))
        
            for pi_charge_name,pi_print in zip(pi_charge_names,pi_prints):
                if do_all_vars:
                    eepi   = pd.read_csv(e_e_pi_FreeP_data_path
                                         +'skimmed_SIDIS_'
                                         +FreeP_prefix + '_'
                                         +'%06d_e_%s_selected_eepi_kinematics.csv'%(runnum,pi_charge_name))
                else: # more economic
                    eepi   = pd.read_csv(e_e_pi_FreeP_data_path
                                         +'skimmed_SIDIS_'
                                         +FreeP_prefix + '_'
                                         +'%06d_e_%s_selected_eepi_kinematics.csv'%(runnum,pi_charge_name),
                                     usecols=['runnum','evnum',
                                              'e_P','e_Theta','e_Phi',
                                              'pi_P', 'pi_Theta', 'pi_Phi',
                                              'Q2', 'W',
                                              'xB', 'Zpi',
                                              'M_x', 'e_DC_sector', 'pi_DC_sector','pi_qFrame_pT','pi_qFrame_pL'],
                                     dtype={'runnum':int,'evnum': int,
                                            'e_DC_sector':int, 'pi_DC_sector':int,
                                            'e_P':np.half,'e_Theta':np.half,'e_Phi':np.half,
                                            'pi_P':np.half,'pi_Theta':np.half, 'pi_Phi':np.half,
                                            'Q2':np.half,  'W':np.half,
                                            'xB':np.half, 'Zpi':np.half,
                                            'M_x':np.half,
                                            'pi_qFrame_pT':np.half,'pi_qFrame_pL':np.half})
                if runIdx==0: e_e_pi_FreeP[pi_charge_name] = eepi
                else:         e_e_pi_FreeP[pi_charge_name] = pd.concat([e_e_pi_FreeP[pi_charge_name],eepi])
                if fdebug>1: print('Loaded',len(eepi)," p(e,e'"+pi_print+") events")
            #}
        #}
    #}
    if do_e_e_pi_GEMC:#{
        for pi_charge_name,pi_print in zip(pi_charge_names,pi_prints):
            eepi   = pd.read_csv(e_e_pi_GEMC_data_path +'ee%s_p_uniform_distribution.csv'%(pi_charge_name))
#             if do_all_vars:
#                 eepi   = pd.read_csv(e_e_pi_GEMC_data_path +'ee%s_p_uniform_distribution.csv'%(pi_charge_name))
#             else:
#                 eepi   = pd.read_csv(e_e_pi_GEMC_data_path +'ee%s_p_uniform_distribution.csv'%(pi_charge_name),                                                     
#                                      usecols=['runnum','evnum',
#                                                               'e_P','e_Theta','e_Phi',
#                                                               'pi_P', 'pi_Theta', 'pi_Phi',
#                                                               'Q2', 'W',
#                                                               'xB', 'Zpi',
#                                                               'M_x', 'e_DC_sector',
#                                                               'pi_DC_sector','pi_qFrame_pT',
#                                                               'pi_qFrame_pL','pi_qFrame_Phi'],                                     
#                                      dtype={'runnum':int,'evnum': int,
#                                                             'e_DC_sector':int, 'pi_DC_sector':int,
#                                                             'e_P':np.half,'e_Theta':np.half,'e_Phi':np.half,
#                                                             'pi_P':np.half,'pi_Theta':np.half, 'pi_Phi':np.half,
#                                                             'Q2':np.half,  'W':np.half,
#                                                             'xB':np.half, 'Zpi':np.half,
#                                                             'M_x':np.half,
#                                                             'pi_qFrame_pT':np.half,'pi_qFrame_pL':np.half,'pi_qFrame_Phi':np.half})
            e_e_pi_GEMC[pi_charge_name] = eepi
            if fdebug>1: print('Loaded',len(eepi)," simulated (e,e'"+pi_print+") events from a white spectrum")
    #}
    print('Done loading files.')
    
    if fdebug>0:
        print('')
        print('Total statistics:')
        for pi_charge_name,pi_print in zip(pi_charge_names,pi_prints):
            if do_e_e_pi:       print(len(e_e_pi[pi_charge_name])      ," d(e,e'"+pi_print+")  events")
            if do_e_e_pi_n:     print(len(e_e_pi_n[pi_charge_name])    ," d(e,e'"+pi_print+"n) events")
            if do_e_e_pi_FreeP: print(len(e_e_pi_FreeP[pi_charge_name])," p(e,e'"+pi_print+")  events")
    #}
    if do_e_e_pi_GEMC:
        return e_e_pi, e_e_pi_n, e_e_pi_FreeP, e_e_pi_GEMC
    else:
        return e_e_pi, e_e_pi_n, e_e_pi_FreeP
#}
# ----------------------- #

# %%
# subdirname = "sidisdvcs_31Jan2023_commit_2e77f15" 
_,_,_,e_e_pi_GEMC = load_SIDIS_data( do_e_e_pi=False, do_e_e_pi_n=False, do_e_e_pi_FreeP=False, do_e_e_pi_GEMC=True,fdebug=2 );
# Out:
# Loaded 1000255  simulated (e,e'π+) events from a white spectrum
# Loaded 1064461  simulated (e,e'π-) events from a white spectrum
# Done loading files.
#
# Total statistics:

# %% [markdown]
# ## (2) Apply selection cuts not previously imposed

# %%
import time

# %%
Nevents = -1
_,_,_,e_e_pi_GEMC_pass_cuts = apply_further_selection_cuts_to_data(fdebug=0, NeventsMax=Nevents);
# Out:
# Applying selection cuts not previously imposed
# Apply a π+/π- acceptance matching cut on the in p-theta plane
# Applying p-theta on cut for piplus which includes 225816 events
# Applying p-theta on cut for piplus on 225816 events
# 38014 in sector 1
# 37869 in sector 2
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:912: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   NeventsMax=NeventsMax,
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:912: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   NeventsMax=NeventsMax,
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:912: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   NeventsMax=NeventsMax,
# 37085 in sector 3
# 38197 in sector 4
# 37029 in sector 5
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:912: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   NeventsMax=NeventsMax,
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:912: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   NeventsMax=NeventsMax,
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:912: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   NeventsMax=NeventsMax,
# 37622 in sector 6
# Applying p-theta on cut for piminus which includes 200049 events
# Applying p-theta on cut for piminus on 200049 events
# 33205 in sector 1
# 33838 in sector 2
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:912: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   NeventsMax=NeventsMax,
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:912: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   NeventsMax=NeventsMax,
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:912: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   NeventsMax=NeventsMax,
# 32705 in sector 3
# 33830 in sector 4
# 32886 in sector 5
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:912: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   NeventsMax=NeventsMax,
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:912: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   NeventsMax=NeventsMax,
# /Users/erezcohen/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:912: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   NeventsMax=NeventsMax,
# 33585 in sector 6
# Apply a cut on the missing mass of a (e,e'π) reaction: 1.7<Mx<5.0 GeV/c2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [17], line 2
#       1 Nevents = -1
# ----> 2 _,_,_,e_e_pi_GEMC_pass_cuts = apply_further_selection_cuts_to_data(fdebug=0, NeventsMax=Nevents);
#
# File ~/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:1331, in apply_further_selection_cuts_to_data(fdebug, NeventsMax, NMaxPerSubset, doAcceptanceMatchingCut, doApply_minPn_cut, doApply_Mx_cut, W_min)
#    1311     #}
#    1312     return errup,errdw
#    1313 #}
#    1314 # ----------------------- #
#    1315
#    1316
#    1317
#    1318
#    1319
#    1320
#    1321
#    1322
#    1323
#    1324
#    1325
#    1326
#    1327
#    1328
#    1329
#    1330
# -> 1331
#    1332
#    1333
#    1334
#    1335
#    1336
#    1337
#    1338 #
#    1339 #
#    1340 #
#    1341 ## ----------------------- #
#    1342 #def apply_p_theta_acceptance_cut( df_dict=None,
#    1343 #                                 NeventsMax=-1,
#    1344 #                                 NMaxPerSubset = 500000,
#    1345 #                                 fdebug=1):
#    1346 #    '''
#    1347 #        df_dict_after_cut = apply_p_theta_acceptance_cut(df_dict)
#    1348 #
#    1349 #        Apply a π+/π- acceptance matching cut on the in p-\theta plane
#    1350 #        last update July-12, 2022
#    1351 #
#    1352 #    '''
#    1353 #    import numpy as np
#    1354 #    print("Apply a π+/π- acceptance matching cut on the in p-theta plane")
#    1355 #    df_dict_after_cut = dict()
#    1356 #
#    1357 #
#    1358 #    for pi_ch in pi_charge_names:
#    1359 #
#    1360 #        if NeventsMax > 0: NeventsMax = np.min( [NeventsMax, len(df_dict[pi_ch])] )
#    1361 #        else:              NeventsMax = len(df_dict[pi_ch])
#    1362 #        df = df_dict[pi_ch][0:NeventsMax]
#    1363 #        if fdebug: print('Applying p-theta on cut for '+pi_ch+' on %d events'%NeventsMax)
#    1364 #
#    1365 #        # subdivide samples into sub-samples of no more than 1M events each
#    1366 #        Nsubsets  = np.max([1,(int)(NeventsMax/NMaxPerSubset)]);
#    1367 #        if fdebug: print('Subdividing into %d subsets up to %d events'%(Nsubsets,NMaxPerSubset))
#    1368 #
#    1369 #        for subset_idx in range(Nsubsets):#{
#    1370 #            i_min_subset = NMaxPerSubset*subset_idx
#    1371 #            i_max_subset = np.min([NMaxPerSubset*(subset_idx+1), NeventsMax])
#    1372 #            subset_df = df[i_min_subset:i_max_subset]
#    1373 #            good_indices = np.array([])
#    1374 #            if fdebug>1:
#    1375 #                print('subset %d of index %d-%d'%(subset_idx,i_min_subset,i_max_subset-1))
#    1376 #
#    1377 #            # focus on each sector and select the events that pass the p-theta cut
#    1378 #            for sector in range(1,7):#{
#    1379 #                df_in_sector   = subset_df[subset_df.pi_DC_sector == sector]
#    1380 #                pi_P           = np.array(df_in_sector.pi_P)
#    1381 #                theta_min_pi   = pi_min_theta_cut( pi_charge = 'any', sector=sector, p=pi_P )
#    1382 #                good_indices_in_sector = []
#    1383 #                good_indices_in_sector = df_in_sector[ df_in_sector.pi_Theta*r2d > theta_min_pi ].index
#    1384 #                good_indices = np.concatenate([good_indices,good_indices_in_sector])
#    1385 #            #}
#    1386 #            good_indices = np.unique(good_indices)
#    1387 #            subset_df_in_cut = subset_df.loc[good_indices]
#    1388 #            if subset_idx==0: df_after_cut = subset_df_in_cut
#    1389 #            else:             df_after_cut = pd.concat([df_after_cut , subset_df_in_cut])
#    1390 #        #}
#    1391 #        df_dict_after_cut[pi_ch] = df_after_cut
#    1392 #    return df_dict_after_cut
#    1393 ## ----------------------- #
#    1394
#    1395
#    1396
#    1397
#    1398
#    1399
#    1400
#    1401 # ----------------------- #
#    1402 def apply_minPn_cut( df_dict=None, Pn_min = 0.275 ): #{
#    1403     '''
#    1404         df_dict_after_cut = apply_minPn_cut( df_dict, Pn_min = 0.275)
#    1405
#    1406         Apply a cut on the minimal neutron momentum
#    1407
#    1408     '''
#
# File ~/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:1234, in apply_cuts_to_e_e_pi_GEMC(fdebug, NeventsMax, NMaxPerSubset, doAcceptanceMatchingCut, doApply_minPn_cut, doApply_Mx_cut)
#    1231 if Q2_min is None: Q2_min = float(cuts[cuts.parameter=="Q2_min"].value)
#    1232 if Q2_max is None: Q2_max = float(cuts[cuts.parameter=="Q2_max"].value)
# -> 1234 if Pe_min is None: Pe_min = float(cuts[cuts.parameter=="Pe_min"].value)
#    1235 if Pe_max is None: Pe_max = float(cuts[cuts.parameter=="Pe_max"].value)
#    1237 if Ppi_min is None: Ppi_min = float(cuts[cuts.parameter=="Ppi_min"].value)
#
# File ~/Desktop/Software//CLAS12/BAND/SIDIS_at_BAND/PythonAnalysis/python_auxiliary/sidis_analysis_tools.py:1651, in apply_Mx_cut(df_dict, Mx_min, Mx_max)
#    1647 global e_e_pi, e_e_pi_pass_cuts
#    1650 if doAcceptanceMatchingCut:#{
# -> 1651     e_e_pi_after_p_theta_cut = apply_p_theta_acceptance_cut_before_correction( e_e_pi,
#    1652                                                               NeventsMax=NeventsMax,
#    1653                                                               fdebug=fdebug )
#    1654     if fdebug: print('e_e_pi_after_p_theta_cut.keys():',e_e_pi_after_p_theta_cut.keys())
#    1656 #}
#    1657 else:#{
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'M_x'

# %% [markdown]
# ## (3) Extract cross-section ratio as a function of Bjorken $x$
# For a standing proton use $x_B$, defined as
# $ x_B = Q^2/2m_p\omega$

# %%
z_bins   = np.arange(0.3,0.8,0.05)
z_widths = 0.01*np.ones(len(z_bins))
x_bins   = np.linspace(0.22,0.62,11)
x        = (x_bins[1:] + x_bins[:-1])/2
x_err    = (x_bins[1:] - x_bins[:-1])/2
print('x bins:',x_bins)
print('z bins:',z_bins)
for z_bin,z_width in zip(z_bins,z_widths):
    z_min,z_max = z_bin-z_width, z_bin+z_width
    print('%.3f < z < %.3f:'%(z_min,z_max))
# Out:
# x bins: [0.22 0.26 0.3  0.34 0.38 0.42 0.46 0.5  0.54 0.58 0.62]
# z bins: [0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65 0.7  0.75]
# 0.290 < z < 0.310:
# 0.340 < z < 0.360:
# 0.390 < z < 0.410:
# 0.440 < z < 0.460:
# 0.490 < z < 0.510:
# 0.540 < z < 0.560:
# 0.590 < z < 0.610:
# 0.640 < z < 0.660:
# 0.690 < z < 0.710:
# 0.740 < z < 0.760:

# %%
var_label = "standing proton x"
var    = 'xB'
xlabel = "Bjorken $x$"

# %%
results_path = '/Users/erezcohen/Desktop/data/BAND/Results/' + 'Results_9Feb2023/'

# %% [markdown]
# # (4) Extract tabular data and save results to file

# %%
data_path = results_path + 'IntegratedOnKinematics/'
extract_SIDIS_ratio(df_dict  = e_e_pi_pass_cuts,                           
                    x_var    = var ,                    
                    data_path=data_path,                    
                    x_bins   = x_bins,                                               
                    z_bins   = z_bins,                                               
                    z_widths = z_widths,                                               
                    fdebug   = 0,                    
                    W_min    = 2.5,                    
                    prefix   = 'Untagged_SIDIS_ratio_',                                               
                    suffix   = '')

# %% [markdown]
# ## load results and plot them

# %%
prefix = 'Untagged_SIDIS_ratio_'
suffix = ''
SIDIS_results = load_SIDIS_ratio(prefix = prefix, suffix = suffix, doPlotResults=True,data_path=data_path,fdebug=1)
ax = plt.gca()
ax.set_ylim(1,2.5);
# Out:
# Reading files from /Users/erezcohen/Desktop/data/BAND/Results/Results_9Feb2023/IntegratedOnKinematics//
# Done.

# %% [markdown]
# # (5) Extract modified results
# E.g. in different kinematical bins

# %% [markdown]
# ## (5.1) Difference between different beam eneries
#
# Since there are slightly different kinematics - due to the different beam enegries,
# we match the $Q^2$ range for all energies to $3 < Q^2 < 4$ (GeV/c)$^2$

# %%
data_path = results_path + 'DifferentBeamEnergies/'
Q2_min = 4.0
Q2_max = 4.5

# %%
indcs = dict()
e_e_pi_pass_cuts_DifferentEbeam = dict()
for E, rum_min, run_max in zip([10.2,10.4 ,10.6],
                               [6400,11360,6160],
                               [6600,11570,6400]):
    e_e_pi_pass_cuts_DifferentEbeam[E] = dict()
    for pi_ch in pi_charge_names:
        indcs[pi_ch + '%.1f'%E] = np.where( (rum_min < e_e_pi_pass_cuts[pi_ch].runnum)                               
                                           & 
                                           (e_e_pi_pass_cuts[pi_ch].runnum < run_max)) 
        e_e_pi_pass_cuts_DifferentEbeam[E][pi_ch] = e_e_pi_pass_cuts[pi_ch].iloc[indcs[pi_ch + '%.1f'%E]]
        
print('Done')
# Out:
# Done

# %%
for E, rum_min, run_max in zip([10.2,10.4 ,10.6],
                               [6400,11360,6160],
                               [6600,11570,6400]):

    extract_SIDIS_ratio(df_dict  = e_e_pi_pass_cuts_DifferentEbeam[E],
                        x_var    = var ,
                        x_bins   = x_bins,
                        z_bins   = z_bins,
                        z_widths = z_widths,          
                        fdebug   = 0,
                        data_path= data_path,
                        prefix   = 'Untagged_SIDIS_ratio_',                    
                        suffix   = '_E_%.1fGeV_%.1f_Q2_%.1f_GeV'%(E,Q2_min,Q2_max),
                        Q2_min   = Q2_min,
                        Q2_max   = Q2_max)
print('Done extracting cross-sections for different E(beam)')
# Out:
# Done extracting cross-sections for different E(beam)

# %% [markdown]
# ## (5.2) Results in different bins of $M_x$

# %%
data_path= results_path + 'Mx_bins/'
M_x_min_arr = [1.7,2.0,2.5]
M_x_max_arr = [2.5,3.0,3.5]

# %%
for M_x_min,M_x_max in zip(M_x_min_arr,M_x_max_arr):
    print(M_x_min,'<M_x<',M_x_max)
    extract_SIDIS_ratio(df_dict  = e_e_pi_pass_cuts,
                        x_var    = var ,
                        x_bins   = x_bins,
                        z_bins   = z_bins,
                        z_widths = z_widths,          
                        fdebug   = 0,
                        data_path= data_path,
                        prefix   = 'Untagged_SIDIS_ratio_',                    
                        suffix   = '_Mx_%.2f-%.2f_GeV'%(M_x_min,M_x_max),
                        M_x_min  = M_x_min,
                        M_x_max  = M_x_max)
    
print('done.')
# Out:
# 1.7 <M_x< 2.5
# 2.0 <M_x< 3.0
# /opt/homebrew/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/homebrew/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in divide
#   ret = arr.dtype.type(ret / rcount)
# 2.5 <M_x< 3.5
# done.

# %% [markdown]
# ### (5.2.1) bins of $M_x$ and $Q^2$

# %%
data_path= '/Users/erezcohen/Desktop/data/BAND/Results/Results_9Feb2023/Mx_and_Q2_bins/'
M_x_min_arr = [0.0,2.0]
M_x_max_arr = [2.0,4.0]
Q2_min_arr  = [2.0,4.0]
Q2_max_arr  = [4.0,9.0]


for Q2_min,Q2_max in zip(Q2_min_arr,Q2_max_arr):
    print(Q2_min,'<Q2<',Q2_max)

    for M_x_min,M_x_max in zip(M_x_min_arr,M_x_max_arr):
        print('\t',M_x_min,'<M_x<',M_x_max)

        extract_SIDIS_ratio(df_dict  = e_e_pi_pass_cuts,
                            x_var    = var ,
                            x_bins   = x_bins,
                            z_bins   = z_bins,
                            z_widths = z_widths,          
                            fdebug   = 0,
                            data_path= data_path,
                            prefix   = 'Untagged_SIDIS_ratio_',                    
                            suffix   = '_Mx_%.2f-%.2f_GeV_Q2_%.2f-%.2f_GeV'%(M_x_min,M_x_max,Q2_min,Q2_max),
                            Q2_min   = Q2_min,
                            Q2_max   = Q2_max,
                            M_x_min  = M_x_min,
                            M_x_max  = M_x_max)
    
print('done.')
# Out:
# 2.0 <Q2< 4.0
# 	 0.0 <M_x< 2.0
# 	 2.0 <M_x< 4.0
# 4.0 <Q2< 9.0
# 	 0.0 <M_x< 2.0
# 	 2.0 <M_x< 4.0
# done.

# %% [markdown]
# ## (5.3) Results in different bins of $Q^2$ integrated over $W$

# %%
data_path= results_path + 'Q2_bins/'
Q2_min_arr = np.arange(2,8,0.5)
Q2_max_arr = Q2_min_arr + 0.5
Q2_min_arr, Q2_max_arr
# Out:
# (array([2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5]),
#  array([2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]))

# %%
for Q2_min,Q2_max in zip(Q2_min_arr,Q2_max_arr):
    suffix   = '_%.1f_Q2_%.1f'%(Q2_min,Q2_max)
    print(suffix)
    extract_SIDIS_ratio(df_dict  = e_e_pi_pass_cuts, 
                        x_var    = var ,
                        x_bins   = x_bins,
                        z_bins   = z_bins,
                        z_widths = z_widths,          
                        fdebug   = 0,
                        data_path= data_path,
                        prefix   = 'Untagged_SIDIS_ratio_',                    
                        suffix   = suffix,
                        Q2_min   = Q2_min,
                        Q2_max   = Q2_max
                       )
print('done.')
# Out:
# _2.0_Q2_2.5
# _2.5_Q2_3.0
# _3.0_Q2_3.5
# _3.5_Q2_4.0
# _4.0_Q2_4.5
# _4.5_Q2_5.0
# _5.0_Q2_5.5
# _5.5_Q2_6.0
# _6.0_Q2_6.5
# _6.5_Q2_7.0
# _7.0_Q2_7.5
# _7.5_Q2_8.0
# done.

# %% [markdown]
# ## (5.4) Results at high-$Q^2$ in different bins of $p_T$ or $\phi_\pi$

# %%
Q2_min,Q2_max = 4.0,4.5
# Q2_min,Q2_max = 3.0,3.5
# Q2_min,Q2_max = 2.0,2.5

# %%
data_path= results_path + 'pT_bins_%.1f_Q2_%.1f/'%(Q2_min,Q2_max)
pT_min_arr = np.arange(0,1.2,0.3)
pT_max_arr = pT_min_arr + 0.3
pT_min_arr, pT_max_arr
# Out:
# (array([0. , 0.3, 0.6, 0.9]), array([0.3, 0.6, 0.9, 1.2]))

# %%
for pT_min,pT_max in zip(pT_min_arr,pT_max_arr):
    suffix   = '_%.2f_pT_%.2f'%(pT_min,pT_max)
    print(suffix)
    extract_SIDIS_ratio(df_dict  = e_e_pi_pass_cuts, 
                        x_var    = var ,
                        x_bins   = x_bins,
                        z_bins   = z_bins,
                        z_widths = z_widths,          
                        fdebug   = 0,
                        data_path= data_path,
                        prefix   = 'Untagged_SIDIS_ratio_',                    
                        suffix   = suffix,
                        Q2_min   = Q2_min,
                        Q2_max   = Q2_max,
                        pT_min   = pT_min,
                        pT_max   = pT_max,
                       )
print('done.')
# Out:
# _0.00_pT_0.30
# _0.30_pT_0.60
# _0.60_pT_0.90
# _0.90_pT_1.20
# done.

# %%
data_path= results_path + 'phi_bins_%.1f_Q2_%.1f/'%(Q2_min,Q2_max)
phi_min_arr = np.arange(-np.pi,np.pi-np.pi/3,np.pi/3)
phi_max_arr = phi_min_arr + np.pi/3
phi_min_arr, phi_max_arr
# Out:
# (array([-3.14159265e+00, -2.09439510e+00, -1.04719755e+00, -8.88178420e-16,
#          1.04719755e+00,  2.09439510e+00]),
#  array([-2.09439510e+00, -1.04719755e+00, -6.66133815e-16,  1.04719755e+00,
#          2.09439510e+00,  3.14159265e+00]))

# %%
for phi_min,phi_max in zip(phi_min_arr, phi_max_arr):
    suffix   = '_%.2f_phi_%.2f'%(phi_min,phi_max)
    print(suffix)
    extract_SIDIS_ratio(df_dict  = e_e_pi_pass_cuts, 
                        x_var    = var ,
                        x_bins   = x_bins,
                        z_bins   = z_bins,
                        z_widths = z_widths,          
                        fdebug   = 0,
                        data_path= data_path,
                        prefix   = 'Untagged_SIDIS_ratio_',                    
                        suffix   = suffix,
                        Q2_min   = Q2_min,
                        Q2_max   = Q2_max,
                        phi_min   = phi_min,
                        phi_max   = phi_max,
                       )
print('done.')
# Out:
# _-3.14_phi_-2.09
# _-2.09_phi_-1.05
# _-1.05_phi_-0.00
# _-0.00_phi_1.05
# _1.05_phi_2.09
# _2.09_phi_3.14
# done.

# %% [markdown]
# ## (5.5) Results in different bins of $Q^2$ and $W$

# %%
from IPython.display import IFrame
IFrame('Q2.png', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="Q2.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame('W.png', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="W.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
Q2_min_arr = [2.0, 2.8, 3.6]
Q2_max_arr = [2.8, 3.6, 8.0]

W_min_arr = np.linspace(2.5,3.1,3)
W_max_arr = np.linspace(2.8,3.4,3)
# print(W_min_arr)  # print(W_max_arr)

z_bins   = np.arange(0.3,0.8,0.05)
z_widths = 0.01*np.ones(len(z_bins))

# %%
for Q2_min,Q2_max in zip(Q2_min_arr,Q2_max_arr):
    for W_min,W_max in zip(W_min_arr,W_max_arr):
        suffix   = '_%.1f_Q2_%.1f____%.1f_W_%.1f'%(Q2_min,Q2_max,W_min,W_max)
        print(suffix)
        extract_SIDIS_ratio(df_dict  = e_e_pi_pass_cuts, 
                            x_var    = var ,
                            x_bins   = x_bins,
                            z_bins   = z_bins,
                            z_widths = z_widths,          
                            fdebug   = 0,
                            data_path= '/Users/erezcohen/Desktop/data/BAND/Results/Q2_and_W_bins/',
                            prefix   = 'Untagged_SIDIS_ratio_',                    
                            suffix   = suffix,
                            W_min    = W_min,
                            W_max    = W_max,
                            Q2_min   = Q2_min,
                            Q2_max   = Q2_max
                           )

print('done.')
# Out:
# _2.0_Q2_2.8____2.5_W_2.8
# _2.0_Q2_2.8____2.8_W_3.1
# _2.0_Q2_2.8____3.1_W_3.4
# _2.8_Q2_3.6____2.5_W_2.8
# _2.8_Q2_3.6____2.8_W_3.1
# _2.8_Q2_3.6____3.1_W_3.4
# _3.6_Q2_8.0____2.5_W_2.8
# _3.6_Q2_8.0____2.8_W_3.1
# _3.6_Q2_8.0____3.1_W_3.4
# done.

# %%
NQ2 = len(Q2_min_arr)
NW  = len(W_min_arr)
fig = plt.figure(figsize=(16,16),tight_layout=True)
for Q2_min,Q2_max,Q2_idx in zip(Q2_min_arr,Q2_max_arr, range(NQ2)):
    for W_min,W_max,W_idx in zip(W_min_arr,W_max_arr, range(NW)):
        suffix   = '_%.1f_Q2_%.1f____%.1f_W_%.1f'%(Q2_min,Q2_max,W_min,W_max)

        axPlot = fig.add_subplot(NQ2, NW, Q2_idx*NW + W_idx + 1)
        SIDIS_results = load_SIDIS_ratio(prefix = prefix, 
                                         fdebug=3,
                                         axPlot = axPlot, 
                                         titlePlot = '$%.1f < Q^2 < %.1f$ (GeV/c)$^2$, $%.1f < W < %.1f$ GeV/c$^2$'%(Q2_min,Q2_max,W_min,W_max),
                                         data_path= '/Users/erezcohen/Desktop/data/BAND/Results/Q2_and_W_bins/',
                                         suffix = suffix, 
                                         doPlotResults=True, 
                                         Nzbins2Plot=3)
        axPlot.set_xticks([0.2,0.3,0.4,0.5]);
# Out:
# Reading files from /Users/erezcohen/Desktop/data/BAND/Results/Q2_and_W_bins//
# Untagged_SIDIS_ratio_Zpi_min0.290_Zpi_mean_pips0.305_pims0.305_Zpi_max0.310_2.0_Q2_2.8____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.590_Zpi_mean_pips0.600_pims0.600_Zpi_max0.610_2.0_Q2_2.8____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.740_Zpi_mean_pipsnan_pimsnan_Zpi_max0.760_2.0_Q2_2.8____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.640_Zpi_mean_pips0.649_pims0.649_Zpi_max0.660_2.0_Q2_2.8____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.340_Zpi_mean_pips0.350_pims0.350_Zpi_max0.360_2.0_Q2_2.8____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.440_Zpi_mean_pips0.450_pims0.450_Zpi_max0.460_2.0_Q2_2.8____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.690_Zpi_mean_pips0.700_pims0.700_Zpi_max0.710_2.0_Q2_2.8____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.740_Zpi_mean_pips0.750_pims0.750_Zpi_max0.760_2.0_Q2_2.8____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.390_Zpi_mean_pips0.400_pims0.400_Zpi_max0.410_2.0_Q2_2.8____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.690_Zpi_mean_pips0.694_pims0.693_Zpi_max0.710_2.0_Q2_2.8____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.490_Zpi_mean_pips0.500_pims0.500_Zpi_max0.510_2.0_Q2_2.8____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.540_Zpi_mean_pips0.550_pims0.550_Zpi_max0.560_2.0_Q2_2.8____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.640_Zpi_mean_pips0.650_pims0.650_Zpi_max0.660_2.0_Q2_2.8____2.5_W_2.8.csv
# Done.
# Reading files from /Users/erezcohen/Desktop/data/BAND/Results/Q2_and_W_bins//
# Untagged_SIDIS_ratio_Zpi_min0.440_Zpi_mean_pips0.450_pims0.450_Zpi_max0.460_2.0_Q2_2.8____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.740_Zpi_mean_pips0.747_pims0.747_Zpi_max0.760_2.0_Q2_2.8____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.740_Zpi_mean_pips0.750_pims0.750_Zpi_max0.760_2.0_Q2_2.8____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.690_Zpi_mean_pips0.700_pims0.700_Zpi_max0.710_2.0_Q2_2.8____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.390_Zpi_mean_pips0.400_pims0.400_Zpi_max0.410_2.0_Q2_2.8____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.540_Zpi_mean_pips0.550_pims0.550_Zpi_max0.560_2.0_Q2_2.8____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.490_Zpi_mean_pips0.500_pims0.500_Zpi_max0.510_2.0_Q2_2.8____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.640_Zpi_mean_pips0.650_pims0.650_Zpi_max0.660_2.0_Q2_2.8____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.590_Zpi_mean_pips0.600_pims0.600_Zpi_max0.610_2.0_Q2_2.8____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.290_Zpi_mean_pips0.305_pims0.305_Zpi_max0.310_2.0_Q2_2.8____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.690_Zpi_mean_pips0.699_pims0.699_Zpi_max0.710_2.0_Q2_2.8____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.340_Zpi_mean_pips0.350_pims0.350_Zpi_max0.360_2.0_Q2_2.8____2.8_W_3.1.csv
# Done.
# Reading files from /Users/erezcohen/Desktop/data/BAND/Results/Q2_and_W_bins//
# Untagged_SIDIS_ratio_Zpi_min0.390_Zpi_mean_pips0.400_pims0.400_Zpi_max0.410_2.0_Q2_2.8____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.740_Zpi_mean_pips0.750_pims0.750_Zpi_max0.760_2.0_Q2_2.8____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.690_Zpi_mean_pips0.700_pims0.700_Zpi_max0.710_2.0_Q2_2.8____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.440_Zpi_mean_pips0.450_pims0.450_Zpi_max0.460_2.0_Q2_2.8____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.640_Zpi_mean_pips0.650_pims0.650_Zpi_max0.660_2.0_Q2_2.8____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.540_Zpi_mean_pips0.550_pims0.550_Zpi_max0.560_2.0_Q2_2.8____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.490_Zpi_mean_pips0.500_pims0.500_Zpi_max0.510_2.0_Q2_2.8____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.590_Zpi_mean_pips0.600_pims0.600_Zpi_max0.610_2.0_Q2_2.8____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.290_Zpi_mean_pips0.305_pims0.305_Zpi_max0.310_2.0_Q2_2.8____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.740_Zpi_mean_pips0.749_pims0.749_Zpi_max0.760_2.0_Q2_2.8____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.340_Zpi_mean_pips0.350_pims0.350_Zpi_max0.360_2.0_Q2_2.8____3.1_W_3.4.csv
# Done.
# Reading files from /Users/erezcohen/Desktop/data/BAND/Results/Q2_and_W_bins//
# Untagged_SIDIS_ratio_Zpi_min0.640_Zpi_mean_pips0.650_pims0.650_Zpi_max0.660_2.8_Q2_3.6____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.540_Zpi_mean_pips0.550_pims0.550_Zpi_max0.560_2.8_Q2_3.6____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.490_Zpi_mean_pips0.500_pims0.500_Zpi_max0.510_2.8_Q2_3.6____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.740_Zpi_mean_pips0.750_pims0.750_Zpi_max0.760_2.8_Q2_3.6____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.690_Zpi_mean_pips0.700_pims0.700_Zpi_max0.710_2.8_Q2_3.6____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.440_Zpi_mean_pips0.450_pims0.450_Zpi_max0.460_2.8_Q2_3.6____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.690_Zpi_mean_pips0.693_pims0.693_Zpi_max0.710_2.8_Q2_3.6____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.390_Zpi_mean_pips0.400_pims0.400_Zpi_max0.410_2.8_Q2_3.6____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.740_Zpi_mean_pipsnan_pimsnan_Zpi_max0.760_2.8_Q2_3.6____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.590_Zpi_mean_pips0.599_pims0.600_Zpi_max0.610_2.8_Q2_3.6____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.340_Zpi_mean_pips0.350_pims0.350_Zpi_max0.360_2.8_Q2_3.6____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.640_Zpi_mean_pips0.649_pims0.649_Zpi_max0.660_2.8_Q2_3.6____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.590_Zpi_mean_pips0.600_pims0.600_Zpi_max0.610_2.8_Q2_3.6____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.290_Zpi_mean_pips0.305_pims0.305_Zpi_max0.310_2.8_Q2_3.6____2.5_W_2.8.csv
# Done.
# Reading files from /Users/erezcohen/Desktop/data/BAND/Results/Q2_and_W_bins//
# Untagged_SIDIS_ratio_Zpi_min0.340_Zpi_mean_pips0.350_pims0.350_Zpi_max0.360_2.8_Q2_3.6____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.690_Zpi_mean_pips0.699_pims0.699_Zpi_max0.710_2.8_Q2_3.6____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.290_Zpi_mean_pips0.305_pims0.305_Zpi_max0.310_2.8_Q2_3.6____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.590_Zpi_mean_pips0.600_pims0.600_Zpi_max0.610_2.8_Q2_3.6____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.640_Zpi_mean_pips0.650_pims0.650_Zpi_max0.660_2.8_Q2_3.6____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.490_Zpi_mean_pips0.500_pims0.500_Zpi_max0.510_2.8_Q2_3.6____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.540_Zpi_mean_pips0.550_pims0.550_Zpi_max0.560_2.8_Q2_3.6____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.690_Zpi_mean_pips0.700_pims0.700_Zpi_max0.710_2.8_Q2_3.6____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.740_Zpi_mean_pips0.750_pims0.750_Zpi_max0.760_2.8_Q2_3.6____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.440_Zpi_mean_pips0.450_pims0.450_Zpi_max0.460_2.8_Q2_3.6____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.740_Zpi_mean_pips0.746_pims0.746_Zpi_max0.760_2.8_Q2_3.6____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.390_Zpi_mean_pips0.400_pims0.400_Zpi_max0.410_2.8_Q2_3.6____2.8_W_3.1.csv
# Done.
# Reading files from /Users/erezcohen/Desktop/data/BAND/Results/Q2_and_W_bins//
# Untagged_SIDIS_ratio_Zpi_min0.690_Zpi_mean_pips0.699_pims0.699_Zpi_max0.710_2.8_Q2_3.6____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.340_Zpi_mean_pips0.350_pims0.350_Zpi_max0.360_2.8_Q2_3.6____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.740_Zpi_mean_pips0.748_pims0.748_Zpi_max0.760_2.8_Q2_3.6____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.740_Zpi_mean_pips0.749_pims0.749_Zpi_max0.760_2.8_Q2_3.6____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.290_Zpi_mean_pips0.305_pims0.305_Zpi_max0.310_2.8_Q2_3.6____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.590_Zpi_mean_pips0.600_pims0.600_Zpi_max0.610_2.8_Q2_3.6____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.490_Zpi_mean_pips0.500_pims0.500_Zpi_max0.510_2.8_Q2_3.6____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.540_Zpi_mean_pips0.550_pims0.550_Zpi_max0.560_2.8_Q2_3.6____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.640_Zpi_mean_pips0.650_pims0.650_Zpi_max0.660_2.8_Q2_3.6____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.690_Zpi_mean_pips0.699_pims0.700_Zpi_max0.710_2.8_Q2_3.6____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.390_Zpi_mean_pips0.400_pims0.400_Zpi_max0.410_2.8_Q2_3.6____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.440_Zpi_mean_pips0.450_pims0.450_Zpi_max0.460_2.8_Q2_3.6____3.1_W_3.4.csv
# Done.
# Reading files from /Users/erezcohen/Desktop/data/BAND/Results/Q2_and_W_bins//
# Untagged_SIDIS_ratio_Zpi_min0.740_Zpi_mean_pipsnan_pimsnan_Zpi_max0.760_3.6_Q2_8.0____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.640_Zpi_mean_pips0.649_pims0.649_Zpi_max0.660_3.6_Q2_8.0____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.340_Zpi_mean_pips0.350_pims0.350_Zpi_max0.360_3.6_Q2_8.0____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.590_Zpi_mean_pips0.600_pims0.600_Zpi_max0.610_3.6_Q2_8.0____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.290_Zpi_mean_pips0.305_pims0.305_Zpi_max0.310_3.6_Q2_8.0____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.590_Zpi_mean_pips0.599_pims0.599_Zpi_max0.610_3.6_Q2_8.0____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.540_Zpi_mean_pips0.550_pims0.550_Zpi_max0.560_3.6_Q2_8.0____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.490_Zpi_mean_pips0.500_pims0.500_Zpi_max0.510_3.6_Q2_8.0____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.640_Zpi_mean_pips0.650_pims0.650_Zpi_max0.660_3.6_Q2_8.0____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.690_Zpi_mean_pips0.692_pims0.692_Zpi_max0.710_3.6_Q2_8.0____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.440_Zpi_mean_pips0.450_pims0.450_Zpi_max0.460_3.6_Q2_8.0____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.740_Zpi_mean_pips0.750_pims0.750_Zpi_max0.760_3.6_Q2_8.0____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.690_Zpi_mean_pips0.700_pims0.700_Zpi_max0.710_3.6_Q2_8.0____2.5_W_2.8.csv
# Untagged_SIDIS_ratio_Zpi_min0.390_Zpi_mean_pips0.400_pims0.400_Zpi_max0.410_3.6_Q2_8.0____2.5_W_2.8.csv
# Done.
# Reading files from /Users/erezcohen/Desktop/data/BAND/Results/Q2_and_W_bins//
# Untagged_SIDIS_ratio_Zpi_min0.490_Zpi_mean_pips0.500_pims0.500_Zpi_max0.510_3.6_Q2_8.0____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.540_Zpi_mean_pips0.550_pims0.550_Zpi_max0.560_3.6_Q2_8.0____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.740_Zpi_mean_pips0.745_pims0.745_Zpi_max0.760_3.6_Q2_8.0____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.640_Zpi_mean_pips0.650_pims0.650_Zpi_max0.660_3.6_Q2_8.0____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.440_Zpi_mean_pips0.450_pims0.450_Zpi_max0.460_3.6_Q2_8.0____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.690_Zpi_mean_pips0.700_pims0.700_Zpi_max0.710_3.6_Q2_8.0____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.740_Zpi_mean_pips0.750_pims0.750_Zpi_max0.760_3.6_Q2_8.0____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.390_Zpi_mean_pips0.400_pims0.400_Zpi_max0.410_3.6_Q2_8.0____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.690_Zpi_mean_pips0.699_pims0.699_Zpi_max0.710_3.6_Q2_8.0____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.340_Zpi_mean_pips0.350_pims0.350_Zpi_max0.360_3.6_Q2_8.0____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.290_Zpi_mean_pips0.305_pims0.305_Zpi_max0.310_3.6_Q2_8.0____2.8_W_3.1.csv
# Untagged_SIDIS_ratio_Zpi_min0.590_Zpi_mean_pips0.600_pims0.600_Zpi_max0.610_3.6_Q2_8.0____2.8_W_3.1.csv
# Done.
# Reading files from /Users/erezcohen/Desktop/data/BAND/Results/Q2_and_W_bins//
# Untagged_SIDIS_ratio_Zpi_min0.740_Zpi_mean_pips0.745_pims0.745_Zpi_max0.760_3.6_Q2_8.0____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.640_Zpi_mean_pips0.650_pims0.650_Zpi_max0.660_3.6_Q2_8.0____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.390_Zpi_mean_pips0.400_pims0.399_Zpi_max0.410_3.6_Q2_8.0____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.490_Zpi_mean_pips0.500_pims0.500_Zpi_max0.510_3.6_Q2_8.0____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.540_Zpi_mean_pips0.550_pims0.550_Zpi_max0.560_3.6_Q2_8.0____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.740_Zpi_mean_pips0.746_pims0.746_Zpi_max0.760_3.6_Q2_8.0____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.390_Zpi_mean_pips0.400_pims0.400_Zpi_max0.410_3.6_Q2_8.0____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.440_Zpi_mean_pips0.450_pims0.450_Zpi_max0.460_3.6_Q2_8.0____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.340_Zpi_mean_pips0.350_pims0.350_Zpi_max0.360_3.6_Q2_8.0____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.690_Zpi_mean_pips0.699_pims0.699_Zpi_max0.710_3.6_Q2_8.0____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.290_Zpi_mean_pips0.305_pims0.305_Zpi_max0.310_3.6_Q2_8.0____3.1_W_3.4.csv
# Untagged_SIDIS_ratio_Zpi_min0.590_Zpi_mean_pips0.600_pims0.600_Zpi_max0.610_3.6_Q2_8.0____3.1_W_3.4.csv
# Done.

# %% [markdown]
# ## (5.6) Results for many more bins in $z$

# %%
# z_bins   = np.arange(0.3,0.8,0.01)
# z_widths = 0.001*np.ones(len(z_bins))

# prefix = 'Untagged_SIDIS_ratio_'
# suffix = ''

# %%
# extract_SIDIS_ratio(df_dict  = e_e_pi_pass_cuts,                                
#                            x_var    = var ,                           
#                            x_bins   = x_bins,                           
#                            z_bins   = z_bins,                           
#                            z_widths = z_widths,                           
#                            fdebug   = 0,
#                            prefix   = 'Untagged_SIDIS_ratio_',
#                             data_path= '/Users/erezcohen/Desktop/data/BAND/Results/Q2_and_W_bins/many_z_bins/',
#                            suffix   = '')
# Out:
# /opt/homebrew/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/homebrew/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in divide
#   ret = arr.dtype.type(ret / rcount)

# %%
# SIDIS_results = load_SIDIS_ratio_DataFrame(z_bins=z_bins,z_widths=z_widths,
#                                            prefix = prefix, suffix = suffix, 
#                                            doPlotResults=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [32], line 1
# ----> 1 SIDIS_results = load_SIDIS_ratio_DataFrame(z_bins=z_bins,z_widths=z_widths,
#       2                                            prefix = prefix, suffix = suffix,
#       3                                            doPlotResults=True)
#
# NameError: name 'load_SIDIS_ratio_DataFrame' is not defined

# %% [markdown]
# # (6) Results with no acceptance matching cut in $p-\theta$

# %%
Nevents = -1
t0= time.time()
e_e_pi_pass_cuts_no_p_theta_cut,_,_ = apply_further_selection_cuts_to_data(fdebug=2,
                                                                           NeventsMax=Nevents, 
                                                                           doAcceptanceMatchingCut=False);
t1 = time.time() 
print("Time elapsed: %.2f"%(t1 - t0), 'sec (%g us/event)'%((t1 - t0)/Nevents*1.e6)) # CPU seconds elapsed (floating point)

# %%
save_SIDIS_ratio_DataFrame(df_dict  = e_e_pi_pass_cuts_no_p_theta_cut,                                
                           x_var    = var ,                           
                           x_bins   = x_bins,                           
                           z_bins   = z_bins,                           
                           z_widths = z_widths,                           
                           fdebug   = 0,
                           prefix   = 'Untagged_SIDIS_ratio_',                           
                           suffix   = '_No_AcceptanceMatchingCut')

# %%
prefix = 'Untagged_SIDIS_ratio_'
suffix = '_No_AcceptanceMatchingCut'
SIDIS_results = load_SIDIS_ratio_DataFrame(prefix = prefix, suffix = suffix, doPlotResults=True)

# %% [markdown]
# # arxiv

# %% [markdown]
# ## Check the impact of beam charge normalization on the data

# %%
e_e_pi_pass_cuts['piplus'].runnum

# %%
# Rpips2pims, Rpips2pims_errup, Rpips2pims_errdw = dict(), dict(), dict()
# Y, dY = dict(),dict()
# for z_bin,z_width in zip(z_bins,z_widths):
#     z_min,z_max = z_bin-z_width,z_bin+z_width
#     (Rpips2pims[z_bin],
#      Rpips2pims_errup[z_bin], 
#      Rpips2pims_errdw[z_bin],_,_) = compute_ratio_pips_to_pims(df_dict=e_e_pi_pass_cuts  , 
#                                                              var=var, 
#                                                              bins=x_bins, 
#                                                              z_min=z_min,z_max=z_max)

#     # fit to a constant 
#     y    = Rpips2pims[z_bin]
#     y_err= (Rpips2pims_errup[z_bin],Rpips2pims_errdw[z_bin])
#     p,cov = np.polyfit(x,y,deg=0,cov=True)
#     Y[z_bin],dY[z_bin] = p[0],cov[0,0]

#     # print(z_bin,Rpips2pims_n[z_bin],Rpips2pims_n_errup[z_bin],Rpips2pims_n_errdw[z_bin])
# print('done')

# %%
# fig = plt.figure(figsize=(9,6))
# ax  = fig.add_subplot(1,1,1)
# for z_bin,z_width in zip(z_bins,z_widths):
#     y    = Rpips2pims[z_bin]
#     y_err= (Rpips2pims_errup[z_bin],Rpips2pims_errdw[z_bin])
#     x_fit = np.linspace(np.min(x),np.max(x),100)
#     y_dw = (Y[z_bin]-dY[z_bin])*np.ones(len(x_fit))
#     y_up = (Y[z_bin]+dY[z_bin])*np.ones(len(x_fit))

#     # plot
#     l=ax.errorbar(x=x, xerr=x_err,  y=y, yerr=y_err,
#                 marker='o',markeredgecolor='k',
#                 label='$z=%.2f\pm%.2f, (\pi^+/\pi^-)=%.2f\pm%.2f$'%(z_bin,z_width,Y[z_bin],dY[z_bin]))
    
#     ax.fill_between( x_fit, y_dw, y_up, color=l[0].get_color(), alpha=0.1)
# set_axes(ax,xlabel,"$N(e,e'\pi^+)/N(e,e'\pi^-)$",
#          title="$\pi^+/\pi^-$ ratio as a function of $x_B$ without a tagged neutron",
#          do_add_grid=True, do_add_legend=True, fontsize=18,
#         );
# plt.legend(bbox_to_anchor=(1,1.05),loc='best',fontsize=18)

# %% [markdown]
# ### Improve analysis timing with a focus on apply_further_selection_cuts_to_data()
# Check timing of the function and improve it, as well as memory usage

# %%
import timeit
timeit.timeit("apply_further_selection_cuts_to_data(fdebug=2, NeventsMax=-1)", 
              setup="from __main__ import apply_further_selection_cuts_to_data",number=1)

# %%
e_e_pi[pi_ch].keys()
# retain only the most important features to reduce memory usage by a large pandas DataFrame
reduced_e_e_pi = dict()
for pi_ch in pi_charge_names:
    reduced_e_e_pi[pi_ch] = e_e_pi[pi_ch][['runnum','evnum',
                                           'e_P','e_Theta','e_Phi', 
                                           'pi_P', 'pi_Theta', 'pi_Phi', 
                                           'Q2', 'W', 'xB', 'Zpi',
                                           'M_X', 'e_DC_sector', 'pi_DC_sector']]
    reduced_e_e_pi[pi_ch] = reduced_e_e_pi[pi_ch].astype({"evnum": int,
                                                          "e_P":np.half,"e_Theta":np.half,"e_Phi":np.half,
                                                          "pi_P":np.half,'pi_Theta':np.half, 'pi_Phi':np.half,
                                                          'Q2':np.half, 'W':np.half, 'xB':np.half, 'Zpi':np.half,
                                                          'M_X':np.half, })

reduced_e_e_pi[pi_ch][0:5]

# %%
for pi_ch in pi_charge_names:
    print(pi_ch)
    print('before cuts')
    print(e_e_pi[pi_ch].info(memory_usage="deep",verbose=False))
    print(' ')    
    # print('reduced dataframe before cuts')
    # print(reduced_e_e_pi[pi_ch].info(memory_usage="deep",verbose=False))
    # print(' ')
    print('after cuts')
    print(e_e_pi_pass_cuts[pi_ch].info(memory_usage="deep",verbose=False))
    print(' ')

# %%
e_e_pi_pass_cuts[pi_ch].index
